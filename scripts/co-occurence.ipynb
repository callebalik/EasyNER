# %% [markdown]
# ## Setup

# %%
import os
from glob import glob
import json
import re
from tqdm.notebook import tqdm
import itertools
import pandas as pd


# Setup
input_folder = "/proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/"
sorted_files = sorted(glob(f'{input_folder}*.json'),key=lambda f: int(''.join(filter(str.isdigit, f))))

for i in sorted_files[:10]:
    print(i)
# Out:
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged1.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged2.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged3.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged4.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged5.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged6.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged7.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged8.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged9.json
# /proj/berzelius-2021-21/users/x_caoll/EasyNer_ner_output/merged/merged10.json

# %% [markdown]
# ## Old code - Now refactored in co_occurence.py

# %%
def load_json(input_file):
    with open(input_file, "r",encoding="utf-8") as f:
        return json.loads(f.read())

def get_batch_index(input_file, k="n"):
    m = re.search(r'\d+$', input_file)
    return int(m.group()) if m else None
    #return int(os.path.splitext(os.path.basename(input_file))[0].split(k)[-1])
    
        

def get_pairs(sorted_files, entity1= "disease", entity2="chemical"):
    '''
    Description:
        get pairs of entity1 and entity2 from the list of articles 
    Parameters:
        sorted_files: sorted files from folder
        output_file: dataframe
        entity1: first entity
        entity2: second entity
        
    Returns:
        dictionary of pairs
    '''
    d = {}
    for input_file in tqdm(sorted_files):
        articles = {}
        # d = load_json(input_file=input_file)
        # batch = {k:d[k] for k in list(d)[:20]}
        batch = load_json(input_file=input_file)
        batch_idx = get_batch_index(input_file=input_file)
    
        
        for idx in batch:
            article=batch[idx]
            
            for s_idx, sent in enumerate(article["sentences"]):
                if len(sent["entities"])>=2:
                    if entity1 in sent["entities"] and entity2 in sent["entities"]:
                        
                        # create an entry for the dict for e1
                        for e1 in sent["entities"][entity1]:
                            if e1 not in d:
                                d[e1] = {}
                            
                            #for each pair e1 e2 create an entry in the subdict
                            for e2 in sent["entities"][entity2]:
                                if e2 not in d[e1]:
                                    d[e1][e2] = {"freq":0, "pmid":set(), "sent":set()}

                                d[e1][e2]["freq"]+=1
                                d[e1][e2]["pmid"].update([idx])
                                d[e1][e2]["sent"].update([sent["text"]])
                        


    return d

def get_self_pairs(sorted_files, entity= "disease"):
    '''
    Description:
        get co occurrance pairs within same model from the list of articles 
    Parameters:
        sorted_files: sorted files from folder
        output_file: dataframe
        entity1: first entity
        entity2: second entity
        
    Returns:
        dictionary of pairs
    '''
    d = {}
    l = []
    for input_file in tqdm(sorted_files):
        articles = {}
        # d = load_json(input_file=input_file)
        # batch = {k:d[k] for k in list(d)[:20]}
        batch = load_json(input_file=input_file)
        batch_idx = get_batch_index(input_file=input_file)
    
        
        for idx in tqdm(batch, desc=f'batch:{batch_idx}'):
            article=batch[idx]
            
            for s_idx, sent in enumerate(article["sentences"]):
                if entity in sent["entities"]: 
                    if len(sent["entities"][entity])>=2:
                        
                        for i in range(len(sent["entities"][entity])):
                            for j in range(i+1, len(sent["entities"][entity])):
                                
                                e1 = sent["entities"][entity][i]
                                s1 = sent["entity_spans"][entity][i]
                                e2 = sent["entities"][entity][j]
                                s2 = sent["entity_spans"][entity][j]
                                if e1!=e2 and len(e1)>1 and len(e2)>1:
                                    
                                    if (e1,e2) in d:
                                        d[(e1,e2)]["freq"]+=1
                                        d[(e1,e2)]["pmid"].update([idx])
#                                         print("first", d)
                                    
                                    elif (e2,e1) in d:
                                        d[(e2,e1)]["freq"]+=1
                                        d[(e2,e1)]["pmid"].update([idx])
#                                         print("sec", d)
                                        
                                    
                                    else:
                                        d[(e1,e2)]= {"freq":1, "pmid":set([idx])}


    return d
# 
# def create_df_from_pairs(d):
#     """
#     create a dataframe of pairs from the nested dictionary
#     """
#     l = []

#     for e1, val in tqdm(sorted(d.items())):
#         for e2 in sorted(val, key=lambda x: (val[x]['freq']), reverse=True):
#             l.append([e1,e2,val[e2]["freq"],",".join(val[e2]["pmid"])])

#     df = pd.DataFrame(l, columns=["entity_1", "entity_2", "frequency", "pmid"])
#     return df

def create_df_from_pairs2(d):
    """
    create a dataframe of pairs from the nested dictionary
    """
    l = []

    for (e1,e2), val in tqdm(sorted(d.items())):
            l.append([e1,e2,val["freq"],",".join(val["pmid"])])

    df = pd.DataFrame(l, columns=["entity_1", "entity_2", "frequency", "pmid"])
    return df.sort_values("frequency", ascending=False)


def get_pairs(sorted_files, entity1= "disease", entity2="chemical"):
    '''
    Description:
        get pairs of entity1 and entity2 from the list of articles 
    Parameters:
        sorted_files: sorted files from folder
        output_file: dataframe
        entity1: first entity
        entity2: second entity
        
    Returns:
        dictionary of pairs
    '''
    d = {}
    for input_file in tqdm(sorted_files):
        articles = {}
        # d = load_json(input_file=input_file)
        # batch = {k:d[k] for k in list(d)[:20]}
        batch = load_json(input_file=input_file)
        batch_idx = get_batch_index(input_file=input_file)
    
        
        for idx in batch:
            article=batch[idx]
            
            for s_idx, sent in enumerate(article["sentences"]):
                if len(sent["entities"])>=2:
                    if entity1 in sent["entities"] and entity2 in sent["entities"]:
                        
                        # create an entry for the dict for e1
                        for e1 in sent["entities"][entity1]:
                            if e1 not in d:
                                d[e1] = {}
                            
                            #for each pair e1 e2 create an entry in the subdict
                            for e2 in sent["entities"][entity2]:
                                if e2 not in d[e1]:
                                    d[e1][e2] = {"freq":0, "pmid":set(), "sent":set()}

                                d[e1][e2]["freq"]+=1
                                d[e1][e2]["pmid"].update([idx])
                                d[e1][e2]["sent"].update([sent["text"]])
                        


    return d

def create_df_from_pairs(d, entity1="disease", entity2="chemicals", entity1_alternate="", entity2_alternate=""):

    l = []

    for e1, val in tqdm(sorted(d.items())):
        for e2 in sorted(val, key=lambda x: (val[x]['freq']), reverse=True):
            l.append([e1,e2,val[e2]["freq"],",".join(val[e2]["pmid"]), val[e2]["sent"]])
    
    columns = [str(entity1), str(entity2), "frequency", "pmid", "sentences"]
    
    if entity1_alternate!="":
        columns[0]=str(entity1_alternate)
    if entity2_alternate!="":
        columns[1]=str(entity2_alternate)
#     print(columns)
    df = pd.DataFrame(l, columns=columns)
    return df.sort_values("frequency", ascending=False)

# %% [markdown]
# # Self pairs ex: disease-disease

# %%
from co_occurence import get_self_pairs
d = get_self_pairs(sorted_files[:2], entity="disease")
d
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x7f2456959550>
# Traceback (most recent call last):
#   File "/home/x_caoll/.conda/envs/easyner_env/lib/python3.9/site-packages/tqdm/std.py", line 1162, in __del__
#     self.close()
#   File "/home/x_caoll/.conda/envs/easyner_env/lib/python3.9/site-packages/tqdm/notebook.py", line 288, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# batch:None: 100%|██████████| 15377/15377 [00:00<00:00, 336024.20it/s]
#
# batch:None: 100%|██████████| 13415/13415 [00:00<00:00, 305385.07it/s]
#
# Processing files: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# {('carcinosarcoma', 'hyperglycemia'): {'freq': 2, 'pmid': {'22'}},
#  ('hypothermia', 'analgesia'): {'freq': 2, 'pmid': {'25', '6716'}},
#  ('haemolytic crisis', 'pnh'): {'freq': 1, 'pmid': {'33'}},
#  ('hypoxia', 'hypercapnia'): {'freq': 20,
#   'pmid': {'103',
#    '13884',
#    '13941',
#    '14277',
#    '16390',
#    '19864',
#    '2406',
#    '37370',
#    '38862',
#    '40092',
#    '42038',
#    '821',
#    '8420',
#    '8991'}},
#  ('respiratory acidosis', 'asphyxia'): {'freq': 1, 'pmid': {'103'}},
#  ('gastritis', 'ulcer'): {'freq': 1, 'pmid': {'123'}},
#  ('gastritis', 'atrophy'): {'freq': 1, 'pmid': {'123'}},
#  ('heartburn', 'epigastric pain'): {'freq': 1, 'pmid': {'123'}},
#  ('heartburn', 'bile vomiting'): {'freq': 1, 'pmid': {'123'}},
#  ('epigastric pain', 'bile vomiting'): {'freq': 1, 'pmid': {'123'}},
#  ('papillary stenosis', 'ductal stones'): {'freq': 1, 'pmid': {'125'}},
#  ('perforation', 'duodenocholedochal junction'): {'freq': 1, 'pmid': {'125'}},
#  ('metabolic alkalaemia', 'decline in cardiac output'): {'freq': 1,
#   'pmid': {'132'}},
#  ('primary', 'liver cell cancer'): {'freq': 1, 'pmid': {'149'}},
#  ('hypertensive', 'hypotensive'): {'freq': 13,
#   'pmid': {'10261',
#    '11308',
#    '152',
#    '19118',
#    '28189',
#    '32359',
#    '39904',
#    '41497',
#    '42418',
#    '44260',
#    '45500',
#    '9626'}},
#  ('hypertensive', 'cerebral haemorrhage'): {'freq': 1, 'pmid': {'152'}},
#  ('hypertensive', 'periarteritis nodosa'): {'freq': 1, 'pmid': {'152'}},
#  ('cerebral haemorrhage', 'periarteritis nodosa'): {'freq': 1,
#   'pmid': {'152'}},
#  ('hemorrhagic', 'hypotension'): {'freq': 2, 'pmid': {'153', '36483'}},
#  ('respiratory acidosis', 'lactic acidosis'): {'freq': 1, 'pmid': {'154'}},
#  ('respiratory acidosis', 'hypoxemia'): {'freq': 1, 'pmid': {'154'}},
#  ('lactic acidosis', 'hypoxemia'): {'freq': 1, 'pmid': {'154'}},
#  ('lactic acidosis', 'secondary polycythemia'): {'freq': 1, 'pmid': {'154'}},
#  ('myocardial infarction', 'hepatocellular damage'): {'freq': 1,
#   'pmid': {'159'}},
#  ('renal hypertension', 'hypertension'): {'freq': 3, 'pmid': {'167'}},
#  ('renal hypertension', 'parenchymal renal disease'): {'freq': 1,
#   'pmid': {'167'}},
#  ('renal hypertension', 'renovascular hypertension'): {'freq': 1,
#   'pmid': {'167'}},
#  ('renal hypertension', 'urological disease'): {'freq': 1, 'pmid': {'167'}},
#  ('renal hypertension', 'endstage renal disease'): {'freq': 1,
#   'pmid': {'167'}},
#  ('hypertension', 'parenchymal renal disease'): {'freq': 3, 'pmid': {'167'}},
#  ('hypertension', 'renovascular hypertension'): {'freq': 7,
#   'pmid': {'167', '32002', '43714', '8201'}},
#  ('hypertension', 'urological disease'): {'freq': 3, 'pmid': {'167'}},
#  ('hypertension', 'endstage renal disease'): {'freq': 3, 'pmid': {'167'}},
#  ('parenchymal renal disease', 'renovascular hypertension'): {'freq': 1,
#   'pmid': {'167'}},
#  ('parenchymal renal disease', 'urological disease'): {'freq': 1,
#   'pmid': {'167'}},
#  ('parenchymal renal disease', 'endstage renal disease'): {'freq': 1,
#   'pmid': {'167'}},
#  ('renovascular hypertension', 'urological disease'): {'freq': 1,
#   'pmid': {'167'}},
#  ('renovascular hypertension', 'endstage renal disease'): {'freq': 1,
#   'pmid': {'167'}},
#  ('urological disease', 'endstage renal disease'): {'freq': 1,
#   'pmid': {'167'}},
#  ('hypoxia', 'ventricular fibrillation'): {'freq': 1, 'pmid': {'210'}},
#  ('metabolic acidosis', 'hypoxia'): {'freq': 3,
#   'pmid': {'210', '40092', '6184'}},
#  ('aortitis syndrome', 'pleural effusion'): {'freq': 1, 'pmid': {'218'}},
#  ('aortitis syndrome', 'aortitis'): {'freq': 1, 'pmid': {'218'}},
#  ('pleural effusion', 'aortitis'): {'freq': 1, 'pmid': {'218'}},
#  ('effusion', 'aortitis syndrome'): {'freq': 1, 'pmid': {'218'}},
#  ('extrahepatic cholestasis', 'anuria'): {'freq': 4, 'pmid': {'232'}},
#  ('cholestasis', 'anuria'): {'freq': 4, 'pmid': {'232'}},
#  ('acidosis', 'alkalosis'): {'freq': 27,
#   'pmid': {'13344',
#    '14471',
#    '14803',
#    '15306',
#    '17949',
#    '240',
#    '24031',
#    '28678',
#    '31597',
#    '34811',
#    '36596',
#    '36597',
#    '36734',
#    '38508',
#    '4259',
#    '54123',
#    '5563',
#    '5845',
#    '6422',
#    '7231',
#    '911'}},
#  ('mast cell infiltration', 'mast cell disease'): {'freq': 1, 'pmid': {'273'}},
#  ('mast cell disease', 'coeliac disease'): {'freq': 1, 'pmid': {'273'}},
#  ('acute diarrhoea', 'chronic diarrhoea'): {'freq': 1, 'pmid': {'274'}},
#  ('acute diarrhoea', 'protein - calorie malnutrition'): {'freq': 1,
#   'pmid': {'274'}},
#  ('chronic diarrhoea', 'protein - calorie malnutrition'): {'freq': 2,
#   'pmid': {'274'}},
#  ('diarrhoea', 'malnutrition'): {'freq': 1, 'pmid': {'274'}},
#  ('toxicity', 'toxicities'): {'freq': 1, 'pmid': {'281'}},
#  ('hypothermia', 'hemodilution'): {'freq': 1, 'pmid': {'292'}},
#  ('hemodilution', 'anemia'): {'freq': 2, 'pmid': {'1846', '293'}},
#  ('hemodilution', 'metabolic acidosis'): {'freq': 3, 'pmid': {'293'}},
#  ('phobias', 'cancer'): {'freq': 1, 'pmid': {'298'}},
#  ('psychiatric', 'anxiety'): {'freq': 2, 'pmid': {'298', '38212'}},
#  ('fluid retention', 'edema'): {'freq': 1, 'pmid': {'346'}},
#  ('fluid retention', 'hypertrichosis'): {'freq': 1, 'pmid': {'346'}},
#  ('fluid retention', 'conjunctival redness'): {'freq': 1, 'pmid': {'346'}},
#  ('edema', 'hypertrichosis'): {'freq': 1, 'pmid': {'346'}},
#  ('edema', 'conjunctival redness'): {'freq': 1, 'pmid': {'346'}},
#  ('hypertrichosis', 'conjunctival redness'): {'freq': 1, 'pmid': {'346'}},
#  ('infection', 'uremia'): {'freq': 1, 'pmid': {'349'}},
#  ('renal insufficiency', 'acute renal failure'): {'freq': 1, 'pmid': {'349'}},
#  ('hypoxia', 'lobar pulmonary artery occlusion'): {'freq': 2, 'pmid': {'353'}},
#  ('myocardial ischaemia', 'coronary occlusion'): {'freq': 1, 'pmid': {'404'}},
#  ('myocardial ischaemia', 'infarction'): {'freq': 1, 'pmid': {'404'}},
#  ('coronary occlusion', 'infarction'): {'freq': 1, 'pmid': {'404'}},
#  ('anxiety', 'irritability'): {'freq': 5,
#   'pmid': {'18689', '25022', '3521', '468'}},
#  ('vasospasm', 'spasm'): {'freq': 1, 'pmid': {'472'}},
#  ('e. acervulina infection', 'e. tenella infection'): {'freq': 1,
#   'pmid': {'476'}},
#  ('fetal acidosis', 'metabolic acidosis'): {'freq': 1, 'pmid': {'480'}},
#  ('fetal acidosis', 'maternogenic fetal metabolic acidosis'): {'freq': 1,
#   'pmid': {'480'}},
#  ('metabolic acidosis', 'maternogenic fetal metabolic acidosis'): {'freq': 1,
#   'pmid': {'480'}},
#  ('acidosis', 'labor'): {'freq': 2, 'pmid': {'480'}},
#  ('heat burns', 'edema'): {'freq': 1, 'pmid': {'515'}},
#  ('deformities', 'dental abscesses'): {'freq': 1, 'pmid': {'519'}},
#  ('deformities', 'trauma'): {'freq': 1, 'pmid': {'519'}},
#  ('dental abscesses', 'trauma'): {'freq': 2, 'pmid': {'39180', '519'}},
#  ('vomiting', 'diarrhea'): {'freq': 5,
#   'pmid': {'15892', '17093', '28976', '44269', '525'}},
#  ('diarrhea', 'vomited'): {'freq': 1, 'pmid': {'525'}},
#  ('graft versus host disease', 'gvhd'): {'freq': 4,
#   'pmid': {'12847', '43062', '43792', '789'}},
#  ('gastric ulcer', 'haemorrhagic gastroduodenitis'): {'freq': 1,
#   'pmid': {'807'}},
#  ('subarachnoid hemorrhage', 'sah'): {'freq': 2, 'pmid': {'820', '822'}},
#  ('spasm', 'ischemic encephalopathy'): {'freq': 1, 'pmid': {'820'}},
#  ('spasm', 'sah'): {'freq': 1, 'pmid': {'820'}},
#  ('ischemic encephalopathy', 'sah'): {'freq': 1, 'pmid': {'820'}},
#  ('intracerebral hematoma', 'subarachnoid hemorrhage'): {'freq': 1,
#   'pmid': {'822'}},
#  ('intracerebral hematoma', 'sah'): {'freq': 1, 'pmid': {'822'}},
#  ('brain tissue hypoxia', 'hemorrhagic'): {'freq': 1, 'pmid': {'822'}},
#  ('strictures', 'gall stones'): {'freq': 1, 'pmid': {'840'}},
#  ('strictures', 'hydropsy'): {'freq': 1, 'pmid': {'840'}},
#  ('gall stones', 'hydropsy'): {'freq': 1, 'pmid': {'840'}},
#  ('viral hepatitis', 'protozoasis'): {'freq': 1, 'pmid': {'858'}},
#  ('fetal anomalies', 'malformed'): {'freq': 1, 'pmid': {'907'}},
#  ('metabolic acidosis', 'alkalosis'): {'freq': 10,
#   'pmid': {'13344', '17498', '17736', '34325', '35552', '911'}},
#  ('hypertonic', 'hypertension'): {'freq': 1, 'pmid': {'913'}},
#  ('acidosis', 'ischaemia'): {'freq': 2, 'pmid': {'44193', '920'}},
#  ('hypothermia', 'hypoxia'): {'freq': 3, 'pmid': {'31720', '930'}},
#  ('hypothermia', 'hypoxic hypoxia'): {'freq': 2, 'pmid': {'31720', '930'}},
#  ('hypothermia', 'acidosis'): {'freq': 1, 'pmid': {'930'}},
#  ('hypoxia', 'hyperoxia'): {'freq': 1, 'pmid': {'935'}},
#  ('respiratory distress', 'shock'): {'freq': 1, 'pmid': {'936'}},
#  ('immunodeficiency diseases', 'acute leukemia'): {'freq': 1, 'pmid': {'937'}},
#  ('immunodeficiency diseases', 'aplastic anemia'): {'freq': 1,
#   'pmid': {'937'}},
#  ('immunodeficiency diseases', 'infection'): {'freq': 1, 'pmid': {'937'}},
#  ('acute leukemia', 'aplastic anemia'): {'freq': 13,
#   'pmid': {'14275',
#    '15688',
#    '16061',
#    '21931',
#    '26718',
#    '30194',
#    '31123',
#    '4261',
#    '42865',
#    '44507',
#    '937'}},
#  ('acute leukemia', 'infection'): {'freq': 1, 'pmid': {'937'}},
#  ('aplastic anemia', 'infection'): {'freq': 1, 'pmid': {'937'}},
#  ('viral disease', 'systemic lupus erythematosus'): {'freq': 1,
#   'pmid': {'938'}},
#  ('ischaemic injury', 'renal ischaemic injury'): {'freq': 1, 'pmid': {'949'}},
#  ('ischaemia', 'renal ischaemic injury'): {'freq': 2, 'pmid': {'4190', '949'}},
#  ('renal ischaemia', 'renal hypothermia'): {'freq': 1, 'pmid': {'949'}},
#  ('renal ischaemia', 'ischaemic injury'): {'freq': 1, 'pmid': {'949'}},
#  ('renal hypothermia', 'ischaemic injury'): {'freq': 1, 'pmid': {'949'}},
#  ('graft versus host reaction', 'gvh'): {'freq': 2, 'pmid': {'42865', '972'}},
#  ('graft versus host reaction', 'lymphosarcoma'): {'freq': 1, 'pmid': {'972'}},
#  ('gvh', 'lymphosarcoma'): {'freq': 1, 'pmid': {'972'}},
#  ('toxic epidermal necrolysis', 'ten'): {'freq': 1, 'pmid': {'972'}},
#  ('renal histological abnormalities',
#   'focal segmental glomerulosclerosis'): {'freq': 1, 'pmid': {'973'}},
#  ('renal histological abnormalities', 'glomerulosclerosis'): {'freq': 1,
#   'pmid': {'973'}},
#  ('focal segmental glomerulosclerosis', 'glomerulosclerosis'): {'freq': 1,
#   'pmid': {'973'}},
#  ('nephritic', 'renal lesions'): {'freq': 1, 'pmid': {'973'}},
#  ('bone marrow depression', 'bmd'): {'freq': 1, 'pmid': {'978'}},
#  ('bone marrow depression', 'depression'): {'freq': 1, 'pmid': {'978'}},
#  ('bmd', 'depression'): {'freq': 1, 'pmid': {'978'}},
#  ('bmd', 'neoplasia'): {'freq': 2, 'pmid': {'978'}},
#  ('bmd', 'leukopenia'): {'freq': 1, 'pmid': {'978'}},
#  ('tumour', 'carcinosarcoma'): {'freq': 2, 'pmid': {'979'}},
#  ('effect hypogenesis', 'tumour'): {'freq': 1, 'pmid': {'979'}},
#  ('hypertonicity', 'pain'): {'freq': 1, 'pmid': {'981'}},
#  ('metachromatic leukodystrophy', 'mld'): {'freq': 12,
#   'pmid': {'11278',
#    '15452',
#    '20311',
#    '20596',
#    '29593',
#    '34126',
#    '36575',
#    '37822',
#    '41211',
#    '43201',
#    '985'}},
#  ('metachromatic leukodystrophy', 'austin disease'): {'freq': 1,
#   'pmid': {'985'}},
#  ('mld', 'austin disease'): {'freq': 1, 'pmid': {'985'}},
#  ('mld', 'deficiency of arylsulfatase'): {'freq': 1, 'pmid': {'985'}},
#  ('mucopolysaccharidoses', 'sanfilippo syndromes'): {'freq': 1,
#   'pmid': {'985'}},
#  ("marek's disease", 'md'): {'freq': 3, 'pmid': {'21547', '50345', '987'}},
#  ('obese', 'ob'): {'freq': 8, 'pmid': {'31866', '38934', '39551', '992'}},
#  ('graft - versus - host - disease', 'gvhd'): {'freq': 1, 'pmid': {'1127'}},
#  ('arrhythmias', 'myocardial infarction'): {'freq': 3,
#   'pmid': {'1133', '50075', '54578'}},
#  ('tumor', 'tumors'): {'freq': 68,
#   'pmid': {'10450',
#    '1140',
#    '14970',
#    '2381',
#    '24754',
#    '25027',
#    '26872',
#    '2936',
#    '3660',
#    '37562',
#    '37817',
#    '38255',
#    '42207',
#    '44818',
#    '46242',
#    '46258',
#    '46776',
#    '46944',
#    '47843',
#    '47896',
#    '48247',
#    '48416',
#    '49053',
#    '49416',
#    '49834',
#    '49934',
#    '50131',
#    '50247',
#    '50665',
#    '50832',
#    '51012',
#    '51922',
#    '52628',
#    '52699',
#    '52757',
#    '53850',
#    '56131',
#    '56223',
#    '56439',
#    '60500',
#    '61194'}},
#  ('cancer', 'normal'): {'freq': 14,
#   'pmid': {'1145',
#  ('gangrene', 'peripheral arterial insufficiency'): {'freq': 1,
#   'pmid': {'1398'}},
#  ('adrenergic tumours', 'parkinsonian'): {'freq': 2, 'pmid': {'1415'}},
#  ('hypogonadal', 'hypopituitary'): {'freq': 1, 'pmid': {'1416'}},
#  ('metabolism', 'lysyl hydroxylase deficiency'): {'freq': 1, 'pmid': {'1448'}},
#  ('metabolism', 'ehlers - danlos syndrome type vi'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('metabolism', 'ehlers - danlos syndrome type vii'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('metabolism', 'ehlers - danlos syndrome type iv'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('metabolism', 'lysyl'): {'freq': 1, 'pmid': {'1448'}},
#  ('metabolism', 's - linked cutis laxa'): {'freq': 1, 'pmid': {'1448'}},
#  ('metabolism', 'ehlers - danlos syndrome type v'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('metabolism', 'osteogenesis imperfecta'): {'freq': 1, 'pmid': {'1448'}},
#  ('lysyl hydroxylase deficiency',
#   'ehlers - danlos syndrome type vi'): {'freq': 1, 'pmid': {'1448'}},
#  ('lysyl hydroxylase deficiency',
#   'ehlers - danlos syndrome type vii'): {'freq': 1, 'pmid': {'1448'}},
#  ('lysyl hydroxylase deficiency',
#   'ehlers - danlos syndrome type iv'): {'freq': 1, 'pmid': {'1448'}},
#  ('lysyl hydroxylase deficiency', 'lysyl'): {'freq': 1, 'pmid': {'1448'}},
#  ('lysyl hydroxylase deficiency', 's - linked cutis laxa'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('lysyl hydroxylase deficiency',
#   'ehlers - danlos syndrome type v'): {'freq': 1, 'pmid': {'1448'}},
#  ('lysyl hydroxylase deficiency', 'osteogenesis imperfecta'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vi',
#   'ehlers - danlos syndrome type vii'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vi',
#   'ehlers - danlos syndrome type iv'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vi', 'lysyl'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vi', 's - linked cutis laxa'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vi',
#   'ehlers - danlos syndrome type v'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vi', 'osteogenesis imperfecta'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vii',
#   'ehlers - danlos syndrome type iv'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vii', 'lysyl'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vii', 's - linked cutis laxa'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vii',
#   'ehlers - danlos syndrome type v'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type vii', 'osteogenesis imperfecta'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type iv', 'lysyl'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type iv', 's - linked cutis laxa'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type iv',
#   'ehlers - danlos syndrome type v'): {'freq': 1, 'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type iv', 'osteogenesis imperfecta'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('lysyl', 's - linked cutis laxa'): {'freq': 1, 'pmid': {'1448'}},
#  ('lysyl', 'ehlers - danlos syndrome type v'): {'freq': 1, 'pmid': {'1448'}},
#  ('lysyl', 'osteogenesis imperfecta'): {'freq': 1, 'pmid': {'1448'}},
#  ('s - linked cutis laxa', 'ehlers - danlos syndrome type v'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('s - linked cutis laxa', 'osteogenesis imperfecta'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('ehlers - danlos syndrome type v', 'osteogenesis imperfecta'): {'freq': 1,
#   'pmid': {'1448'}},
#  ('hypertensive', 'heart failure'): {'freq': 1, 'pmid': {'1454'}},
#  ('comatose', 'head injuries'): {'freq': 1, 'pmid': {'1473'}},
#  ('hypertension', 'hyperventilation'): {'freq': 2, 'pmid': {'1473'}},
#  ('brain - stem lesions', 'cortical lesiosn'): {'freq': 1, 'pmid': {'1473'}},
#  ('tdp', 'ttp'): {'freq': 1, 'pmid': {'1481'}},
#  ('atrophy', 'cryptorchidism'): {'freq': 2, 'pmid': {'1483'}},
#  ('myocardial disease', 'hypertension'): {'freq': 2,
#   'pmid': {'1533', '40234'}},
#  ('polyarteritis nodosa', 'hypersentitivity angiitis'): {'freq': 1,
#   'pmid': {'1533'}},
#  ('polyarteritis nodosa', 'allergic granulomatosis'): {'freq': 2,
#   'pmid': {'1533', '24429'}},
#  ('hypersentitivity angiitis', 'allergic granulomatosis'): {'freq': 1,
#   'pmid': {'1533'}},
#  ('leukemia - lymphoma', 'sll'): {'freq': 1, 'pmid': {'1546'}},
#  ('leukemic', 'leukemia'): {'freq': 4,
#   'pmid': {'14751', '1546', '53787', '53834'}},
#  ('carcinogenesis', 'carcinogenic'): {'freq': 1, 'pmid': {'1550'}},
#  ('hyperventilation', 'acidosis'): {'freq': 7,
#   'pmid': {'15306', '1554', '21198', '43860', '6184'}},
#  ('hyperventilation', 'cardiac arrest'): {'freq': 1, 'pmid': {'1554'}},
#  ('acidosis', 'cardiac arrest'): {'freq': 5,
#   'pmid': {'10218', '1554', '45046'}},
#  ('neurotoxic', 'depression'): {'freq': 1, 'pmid': {'1561'}},
#  ('hypoperfusion', 'shock'): {'freq': 1, 'pmid': {'1563'}},
#  ('hypoperfusion', 'heart failure'): {'freq': 1, 'pmid': {'1563'}},
#  ('shock', 'heart failure'): {'freq': 5, 'pmid': {'1563', '46703', '48183'}},
#  ('tachycardia', 'tachyarrhythmias'): {'freq': 1, 'pmid': {'1563'}},
#  ('tachycardia', 'angina'): {'freq': 1, 'pmid': {'1563'}},
#  ('mineralocorticoid deficiency', 'kidney failure'): {'freq': 1,
#   'pmid': {'1674'}},
#  ('metabolic acidosis', 'hyporeninemic hypoaldosteronism'): {'freq': 2,
#   'pmid': {'1674', '18672'}},
#  ('metabolic acidosis', 'kidney failure'): {'freq': 1, 'pmid': {'1674'}},
#  ('hyporeninemic hypoaldosteronism', 'kidney failure'): {'freq': 1,
#   'pmid': {'1674'}},
#  ('hyperkalemia', 'acidosis'): {'freq': 8, 'pmid': {'1674', '18672', '25018'}},
#  ('hyperkalemia', 'azotemia'): {'freq': 2, 'pmid': {'1674', '25018'}},
#  ('acidosis', 'azotemia'): {'freq': 2, 'pmid': {'1674', '25018'}},
#  ('hyperkalemia', 'hypoaldosteronism'): {'freq': 3, 'pmid': {'1674', '18672'}},
#  ('hypoaldosteronism', 'acidosis'): {'freq': 2, 'pmid': {'1674', '18672'}},
#  ('transmissible gastroenteritis', 'tge'): {'freq': 2,
#   'pmid': {'1684', '9360'}},
#  ('toxemic', 'active labor'): {'freq': 1, 'pmid': {'1696'}},
#  ('tachycardia', 'bradycardia'): {'freq': 9,
#   'pmid': {'1704', '28878', '3073', '42517', '49082', '6505'}},
#  ('mucocutaneous lymph node syndrome', 'mcls'): {'freq': 1, 'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome', 'fever'): {'freq': 1, 'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome',
#   'erythematous skin eruption'): {'freq': 1, 'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome', 'conjunctival congestion'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome', 'dry red fissured lips'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome',
#   'reddened tongue, palms, and soles'): {'freq': 1, 'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome', 'lymphadenopathy'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome', 'diarrhea'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome', 'arthralgia'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('mucocutaneous lymph node syndrome', 'aseptic meningitis'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('mcls', 'fever'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'erythematous skin eruption'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'conjunctival congestion'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'dry red fissured lips'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'reddened tongue, palms, and soles'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'lymphadenopathy'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'diarrhea'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'arthralgia'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'aseptic meningitis'): {'freq': 1, 'pmid': {'1705'}},
#  ('fever', 'erythematous skin eruption'): {'freq': 1, 'pmid': {'1705'}},
#  ('fever', 'conjunctival congestion'): {'freq': 1, 'pmid': {'1705'}},
#  ('fever', 'dry red fissured lips'): {'freq': 1, 'pmid': {'1705'}},
#  ('fever', 'reddened tongue, palms, and soles'): {'freq': 1, 'pmid': {'1705'}},
#  ('fever', 'lymphadenopathy'): {'freq': 2, 'pmid': {'1705', '50605'}},
#  ('fever', 'diarrhea'): {'freq': 4,
#   'pmid': {'1705', '17093', '43437', '5346'}},
#  ('fever', 'arthralgia'): {'freq': 4,
#   'pmid': {'1705', '45056', '49743', '50605'}},
#  ('fever', 'aseptic meningitis'): {'freq': 1, 'pmid': {'1705'}},
#  ('erythematous skin eruption', 'conjunctival congestion'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('erythematous skin eruption', 'dry red fissured lips'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('erythematous skin eruption',
#   'reddened tongue, palms, and soles'): {'freq': 1, 'pmid': {'1705'}},
#  ('erythematous skin eruption', 'lymphadenopathy'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('erythematous skin eruption', 'diarrhea'): {'freq': 1, 'pmid': {'1705'}},
#  ('erythematous skin eruption', 'arthralgia'): {'freq': 1, 'pmid': {'1705'}},
#  ('erythematous skin eruption', 'aseptic meningitis'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('conjunctival congestion', 'dry red fissured lips'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('conjunctival congestion', 'reddened tongue, palms, and soles'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('conjunctival congestion', 'lymphadenopathy'): {'freq': 1, 'pmid': {'1705'}},
#  ('conjunctival congestion', 'diarrhea'): {'freq': 1, 'pmid': {'1705'}},
#  ('conjunctival congestion', 'arthralgia'): {'freq': 1, 'pmid': {'1705'}},
#  ('conjunctival congestion', 'aseptic meningitis'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('dry red fissured lips', 'reddened tongue, palms, and soles'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('dry red fissured lips', 'lymphadenopathy'): {'freq': 1, 'pmid': {'1705'}},
#  ('dry red fissured lips', 'diarrhea'): {'freq': 1, 'pmid': {'1705'}},
#  ('dry red fissured lips', 'arthralgia'): {'freq': 1, 'pmid': {'1705'}},
#  ('dry red fissured lips', 'aseptic meningitis'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('reddened tongue, palms, and soles', 'lymphadenopathy'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('reddened tongue, palms, and soles', 'diarrhea'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('reddened tongue, palms, and soles', 'arthralgia'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('reddened tongue, palms, and soles', 'aseptic meningitis'): {'freq': 1,
#   'pmid': {'1705'}},
#  ('lymphadenopathy', 'diarrhea'): {'freq': 2, 'pmid': {'1705', '7134'}},
#  ('lymphadenopathy', 'arthralgia'): {'freq': 3,
#   'pmid': {'1705', '50605', '7134'}},
#  ('lymphadenopathy', 'aseptic meningitis'): {'freq': 2,
#   'pmid': {'1705', '7134'}},
#  ('diarrhea', 'arthralgia'): {'freq': 2, 'pmid': {'1705', '7134'}},
#  ('diarrhea', 'aseptic meningitis'): {'freq': 2, 'pmid': {'1705', '7134'}},
#  ('arthralgia', 'aseptic meningitis'): {'freq': 2, 'pmid': {'1705', '7134'}},
#  ('carditis', 'pericarditis'): {'freq': 1, 'pmid': {'1705'}},
#  ('carditis', 'aneurysmal'): {'freq': 1, 'pmid': {'1705'}},
#  ('carditis', 'thrombosis'): {'freq': 1, 'pmid': {'1705'}},
#  ('carditis', 'sudden death'): {'freq': 1, 'pmid': {'1705'}},
#  ('pericarditis', 'aneurysmal'): {'freq': 1, 'pmid': {'1705'}},
#  ('pericarditis', 'thrombosis'): {'freq': 1, 'pmid': {'1705'}},
#  ('pericarditis', 'sudden death'): {'freq': 1, 'pmid': {'1705'}},
#  ('aneurysmal', 'thrombosis'): {'freq': 1, 'pmid': {'1705'}},
#  ('aneurysmal', 'sudden death'): {'freq': 1, 'pmid': {'1705'}},
#  ('thrombosis', 'sudden death'): {'freq': 1, 'pmid': {'1705'}},
#  ('mcls', 'polyarteritis nodosa'): {'freq': 1, 'pmid': {'1705'}},
#  ('acidosis', 'respiratory distress syndrome'): {'freq': 1, 'pmid': {'1706'}},
#  ('hypothermic', 'hypothermia'): {'freq': 5,
#   'pmid': {'11444', '1709', '1961', '22722', '35548'}},
#  ('normothermia', 'panting'): {'freq': 1, 'pmid': {'1710'}},
#  ('nonketotic coma', 'hyperglycemia'): {'freq': 1, 'pmid': {'1717'}},
#  ('nonketotic coma', 'ketoacidosis'): {'freq': 1, 'pmid': {'1717'}},
#  ('nonketotic coma', 'diabetes'): {'freq': 1, 'pmid': {'1717'}},
#  ('hyperglycemia', 'ketoacidosis'): {'freq': 1, 'pmid': {'1717'}},
#  ('hyperglycemia', 'diabetes'): {'freq': 1, 'pmid': {'1717'}},
#  ('ketoacidosis', 'diabetes'): {'freq': 1, 'pmid': {'1717'}},
#  ('alcoholic ketoacidosis', 'hyperketonemia'): {'freq': 1, 'pmid': {'1717'}},
#  ('alcoholic ketoacidosis', 'hyperglycemia'): {'freq': 1, 'pmid': {'1717'}},
#  ('hyperketonemia', 'hyperglycemia'): {'freq': 1, 'pmid': {'1717'}},
#  ('diabetic ketoacidosis', 'glycosuria'): {'freq': 1, 'pmid': {'1717'}},
#  ('capnia', 'acidosis'): {'freq': 1, 'pmid': {'1719'}},
#  ('capnia', 'hypercapnia'): {'freq': 1, 'pmid': {'1719'}},
#  ('acidosis', 'hypercapnia'): {'freq': 16,
#   'pmid': {'10616',
#    '11755',
#    '12691',
#    '13511',
#    '1719',
#    '19864',
#    '31091',
#    '35607',
#    '36421',
#    '38862',
#    '6184'}},
#  ('genetic lesions', 'glnb'): {'freq': 1, 'pmid': {'1744'}},
#  ('genetic lesions', 'glnd'): {'freq': 1, 'pmid': {'1744'}},
#  ('genetic lesions', 'glne'): {'freq': 1, 'pmid': {'1744'}},
#  ('glnb', 'glnd'): {'freq': 1, 'pmid': {'1744'}},
#   'pmid': {'1961'}},
#  ('hypothermia', 'arteriosclerosis'): {'freq': 1, 'pmid': {'1961'}},
#  ('hypothermia', 'cerebrovascular diseases'): {'freq': 1, 'pmid': {'1961'}},
#  ('arteriosclerosis', 'cerebrovascular diseases'): {'freq': 1,
#   'pmid': {'1961'}},
#  ('bilateral carotid occlusion', 'bco'): {'freq': 1, 'pmid': {'1967'}},
#  ('bilateral carotid occlusion', 'narcosis'): {'freq': 1, 'pmid': {'1967'}},
#  ('bco', 'narcosis'): {'freq': 1, 'pmid': {'1967'}},
#  ('haemorrhagic', 'haemorrhage'): {'freq': 1, 'pmid': {'1967'}},
#  ('cardiovascular and respiratory syndromes', 'inflammation'): {'freq': 1,
#   'pmid': {'1979'}},
#  ('cardiovascular and respiratory syndromes', 'allergy'): {'freq': 1,
#   'pmid': {'1979'}},
#  ('cardiovascular and respiratory syndromes', 'anaphylaxis'): {'freq': 1,
#   'pmid': {'1979'}},
#  ('inflammation', 'allergy'): {'freq': 2, 'pmid': {'1979', '52931'}},
#  ('inflammation', 'anaphylaxis'): {'freq': 1, 'pmid': {'1979'}},
#  ('allergy', 'anaphylaxis'): {'freq': 1, 'pmid': {'1979'}},
#  ('parasitemia', 'anaemia'): {'freq': 1, 'pmid': {'1987'}},
#  ('parasitemia', 'thrombus'): {'freq': 1, 'pmid': {'1987'}},
#  ('anaemia', 'thrombus'): {'freq': 1, 'pmid': {'1987'}},
#  ('trypanosomiasis', 'intravascular coagulation'): {'freq': 1,
#   'pmid': {'1987'}},
#  ('lva', 'oedema'): {'freq': 1, 'pmid': {'1991'}},
#  ('dementia', 'mentally retarded'): {'freq': 1, 'pmid': {'1996'}},
#  ('dementia', 'neurologidal diseases'): {'freq': 1, 'pmid': {'1996'}},
#  ('mentally retarded', 'neurologidal diseases'): {'freq': 1, 'pmid': {'1996'}},
#  ('cardiac arrhythmias', 'heart disease'): {'freq': 1, 'pmid': {'2004'}},
#  ('cardiac arrhythmia', 'bronchospasm'): {'freq': 1, 'pmid': {'2007'}},
#  ('crypt abscesses', 'mucosal edema'): {'freq': 1, 'pmid': {'2008'}},
#  ('respiratory distress syndrome', 'rds'): {'freq': 5,
#   'pmid': {'13013', '2013', '38862', '41662', '7768'}},
#  ('respiratory distress syndrome', 'intracranial hemorrhage'): {'freq': 1,
#   'pmid': {'2013'}},
#  ('rds', 'intracranial hemorrhage'): {'freq': 2, 'pmid': {'2013'}},
#  ('dyskinesia', 'psychotic decompensation'): {'freq': 1, 'pmid': {'2021'}},
#  ("takayasu's arteritis", 'lymphadenopathy'): {'freq': 1, 'pmid': {'2023'}},
#  ('gastroesophageal reflux', 'esophagitis'): {'freq': 3,
#   'pmid': {'2024', '22124'}},
#  ('postoperative peritonitis', 'gastro - intestinal fistula'): {'freq': 1,
#   'pmid': {'2036'}},
#  ('postoperative peritonitis', 'hemorrhagic syndrome'): {'freq': 1,
#   'pmid': {'2036'}},
#  ('gastro - intestinal fistula', 'hemorrhagic syndrome'): {'freq': 1,
#   'pmid': {'2036'}},
#  ('haemorrhage', 'hypontensive'): {'freq': 1, 'pmid': {'2080'}},
#  ('placenta praevia', 'respiratory distress'): {'freq': 1, 'pmid': {'2084'}},
#  ('death', 'anoxia'): {'freq': 1, 'pmid': {'2084'}},
#  ('death', 'alveolar collapse'): {'freq': 1, 'pmid': {'2084'}},
#  ('anoxia', 'alveolar collapse'): {'freq': 1, 'pmid': {'2084'}},
#  ('narcosis', 'labour'): {'freq': 1, 'pmid': {'2085'}},
#  ('neuroleptanalgesia', 'labour'): {'freq': 1, 'pmid': {'2085'}},
#  ('hypertonic', 'infection'): {'freq': 1, 'pmid': {'2102'}},
#  ('pyelonephritis', 'renal disease'): {'freq': 1, 'pmid': {'2129'}},
#  ('infection', 'ibv'): {'freq': 1, 'pmid': {'2145'}},
#  ('carcinoma of breast', 'cystic mastitis'): {'freq': 1, 'pmid': {'2274'}},
#  ('carcinoma of breast', 'gynaecomastia'): {'freq': 1, 'pmid': {'2274'}},
#  ('carcinoma of breast', 'normal'): {'freq': 1, 'pmid': {'2274'}},
#  ('cystic mastitis', 'gynaecomastia'): {'freq': 2, 'pmid': {'2274'}},
#  ('cystic mastitis', 'normal'): {'freq': 2, 'pmid': {'2274'}},
#  ('gynaecomastia', 'normal'): {'freq': 2, 'pmid': {'2274'}},
#  ('breast cancer', 'gynaecomastia'): {'freq': 1, 'pmid': {'2274'}},
#  ('breast cancer', 'cystic mastitis'): {'freq': 1, 'pmid': {'2274'}},
#  ('breast cancer', 'normal'): {'freq': 2, 'pmid': {'22554', '2274'}},
#  ('metabolic acidosis', 'depression'): {'freq': 1, 'pmid': {'2340'}},
#  ('pyometra', 'disorder of the uterus'): {'freq': 1, 'pmid': {'2358'}},
#  ('pyometra', 'bacterial infection'): {'freq': 1, 'pmid': {'2358'}},
#  ('disorder of the uterus', 'bacterial infection'): {'freq': 1,
#   'pmid': {'2358'}},
#  ('silicosis', 'pneumoconiosis'): {'freq': 3, 'pmid': {'2357'}},
#  ('pneumoconiosis', 'deterioration of pulmonary function'): {'freq': 1,
#   'pmid': {'2357'}},
#  ('pneumoconiosis', 'emphysema'): {'freq': 1, 'pmid': {'2357'}},
#  ('deterioration of pulmonary function', 'silicosis'): {'freq': 1,
#   'pmid': {'2357'}},
#  ('deterioration of pulmonary function', 'emphysema'): {'freq': 1,
#   'pmid': {'2357'}},
#  ('silicosis', 'emphysema'): {'freq': 1, 'pmid': {'2357'}},
#  ('nausea', 'vomiting'): {'freq': 18,
#   'pmid': {'2377',
#    '30034',
#    '35428',
#    '38177',
#    '39885',
#    '40688',
#    '43821',
#    '44269',
#    '46697',
#    '46956',
#    '53720',
#    '56427',
#    '56988',
#    '57124',
#    '60073',
#    '60156'}},
#  ('nausea', 'headaches'): {'freq': 2, 'pmid': {'2377', '28313'}},
#  ('vomiting', 'headaches'): {'freq': 2, 'pmid': {'13647', '2377'}},
#  ('anxiety', 'amnesia'): {'freq': 1, 'pmid': {'2377'}},
#  ('anxiety', 'nausea'): {'freq': 1, 'pmid': {'2377'}},
#  ('anxiety', 'vomiting'): {'freq': 1, 'pmid': {'2377'}},
#  ('amnesia', 'nausea'): {'freq': 3, 'pmid': {'19025', '2377'}},
#  ('amnesia', 'vomiting'): {'freq': 1, 'pmid': {'2377'}},
#  ('neuromuscular paralysis', 'bradycardia'): {'freq': 1, 'pmid': {'2378'}},
#  ('neuromuscular paralysis', 'cardiovascular disturbances'): {'freq': 1,
#   'pmid': {'2378'}},
#  ('bradycardia', 'cardiovascular disturbances'): {'freq': 1, 'pmid': {'2378'}},
#  ('tachycardia', 'hypertension'): {'freq': 12,
#   'pmid': {'14307',
#    '20256',
#    '2378',
#    '36487',
#    '37368',
#    '38965',
#    '39526',
#    '43103',
#    '7373',
#    '9033'}},
#  ('tachycardia', 'neuromuscular paralysis'): {'freq': 1, 'pmid': {'2378'}},
#  ('hypertension', 'neuromuscular paralysis'): {'freq': 1, 'pmid': {'2378'}},
#  ('paralysis', 'tetanic'): {'freq': 1, 'pmid': {'2378'}},
#  ('colon cancer', 'disease'): {'freq': 2, 'pmid': {'21742', '2379'}},
#  ('tumor', 'ascites'): {'freq': 5,
#   'pmid': {'2381', '28921', '43819', '46779', '47261'}},
#  ('tumors', 'metastases'): {'freq': 3, 'pmid': {'2401', '26872'}},
#  ('hypoxia', 'hepatic cirrhosis'): {'freq': 1, 'pmid': {'2406'}},
#  ('respiratory alkalosis', 'liver failure'): {'freq': 1, 'pmid': {'2406'}},
#  ('respiratory alkalosis', 'hypoxia'): {'freq': 3,
#   'pmid': {'13677', '14304', '2406'}},
#  ('liver failure', 'hypoxia'): {'freq': 5, 'pmid': {'2406'}},
#  ('hypercapnia', 'liver failure'): {'freq': 2, 'pmid': {'2406'}},
#  ('coma', 'cerebromalacia'): {'freq': 1, 'pmid': {'2454'}},
#  ('coma', 'hypoxia'): {'freq': 1, 'pmid': {'2454'}},
#  ('cerebromalacia', 'hypoxia'): {'freq': 1, 'pmid': {'2454'}},
#  ('diabetics', 'diabetic'): {'freq': 1, 'pmid': {'2460'}},
#  ('hypothermia', 'hepatic coma'): {'freq': 1, 'pmid': {'2480'}},
#  ('hyperthermic', 'hypothermia'): {'freq': 1, 'pmid': {'2482'}},
#  ('hyperthermia', 'hypothermia'): {'freq': 8,
#   'pmid': {'2482', '32239', '38317', '45568', '5004'}},
#  ('ulcerative colitis', "crohn's disease"): {'freq': 16,
#   'pmid': {'15752',
#    '21768',
#    '23347',
#    '2509',
#    '33552',
#    '35436',
#    '47700',
#    '47701',
#    '49840',
#    '8957',
#    '9346'}},
#  ('schizophrenia', 'schizophrenic illnesses'): {'freq': 1, 'pmid': {'2524'}},
#  ('meningitis', 'thrombangiitis'): {'freq': 1, 'pmid': {'2527'}},
#  ('luetic endangiitis', 'toxic angiitis'): {'freq': 1, 'pmid': {'2527'}},
#  ('luetic endangiitis', 'collagenoses'): {'freq': 1, 'pmid': {'2527'}},
#  ('toxic angiitis', 'collagenoses'): {'freq': 1, 'pmid': {'2527'}},
#  ('infectious endocarditis', 'mycoses'): {'freq': 1, 'pmid': {'2527'}},
# ...
#  ('sudden and unexpected death', 'periarteritis nodosa'): {'freq': 1,
#   'pmid': {'3150'}},
#  ('mcls', 'arteritis'): {'freq': 1, 'pmid': {'3150'}},
#  ('mcls', 'aneurysm'): {'freq': 1, 'pmid': {'3150'}},
#  ('mcls', 'coronary arteritis'): {'freq': 1, 'pmid': {'3150'}},
#  ('arteritis', 'aneurysm'): {'freq': 1, 'pmid': {'3150'}},
#  ('arteritis', 'coronary arteritis'): {'freq': 1, 'pmid': {'3150'}},
#  ('aneurysm', 'coronary arteritis'): {'freq': 1, 'pmid': {'3150'}},
#  ('periarteritis nodosa', 'vasculitis'): {'freq': 2,
#   'pmid': {'3150', '40388'}},
#  ('gastric congestion', 'weight loss'): {'freq': 1, 'pmid': {'3151'}},
#  ('gastric congestion', 'gastric erosions'): {'freq': 1, 'pmid': {'3151'}},
#  ('gastric congestion', 'hypertension'): {'freq': 1, 'pmid': {'3151'}},
#  ('weight loss', 'gastric erosions'): {'freq': 1, 'pmid': {'3151'}},
#  ('weight loss', 'hypertension'): {'freq': 1, 'pmid': {'3151'}},
#  ('gastric erosions', 'hypertension'): {'freq': 1, 'pmid': {'3151'}},
#  ('myotonic dystrophy', 'duchenne dystrophy'): {'freq': 1, 'pmid': {'3154'}},
#  ('nephritis', 'hypertrophy of adrenals'): {'freq': 1, 'pmid': {'3153'}},
#  ('hypotensive', 'hypertension'): {'freq': 12,
#   'pmid': {'14504',
#    '15323',
#    '22466',
#    '24193',
#    '25351',
#    '3186',
#    '42418',
#    '45432',
#    '6254',
#    '7342'}},
#  ('lichen planus - like eruption', 'lple'): {'freq': 1, 'pmid': {'3194'}},
#  ('graft - versus - host reaction',
#   'lichen planus - like eruption'): {'freq': 1, 'pmid': {'3194'}},
#  ('respiratory insufficiency', 'cardiac failure'): {'freq': 2,
#   'pmid': {'3242'}},
#  ('respiratory insufficiency', 'denutrition'): {'freq': 1, 'pmid': {'3242'}},
#  ('cardiac failure', 'denutrition'): {'freq': 1, 'pmid': {'3242'}},
#  ('status asthmaticus', 'acidosis'): {'freq': 1, 'pmid': {'3243'}},
#  ('status asthmaticus', 'hypercapnia'): {'freq': 1, 'pmid': {'3243'}},
#  ('schizophrenic', 'psychiatric'): {'freq': 4,
#   'pmid': {'27252', '27578', '3251', '37748'}},
#  ('rheumatoid arthritis', 'ra'): {'freq': 9,
#   'pmid': {'20777',
#    '26225',
#    '28650',
#    '31141',
#    '3258',
#    '36289',
#    '49178',
#    '56939'}},
#  ('parkinsonian', 'functional disability'): {'freq': 1, 'pmid': {'3279'}},
#  ('carcinoid', 'tumors'): {'freq': 5, 'pmid': {'3280', '50623', '51682'}},
#  ('neoplasms', 'thymomas'): {'freq': 1, 'pmid': {'3280'}},
#  ('myasthenia gravis', 'red - cell hypoplasia'): {'freq': 1, 'pmid': {'3280'}},
#  ('myasthenia gravis', 'tumors'): {'freq': 1, 'pmid': {'3280'}},
#  ('myasthenia gravis', 'thymomas'): {'freq': 1, 'pmid': {'3280'}},
#  ('red - cell hypoplasia', 'tumors'): {'freq': 1, 'pmid': {'3280'}},
#  ('cancer', 'seminomas'): {'freq': 1, 'pmid': {'3662'}},
#  ('testicular cancer', 'inguinal hernia'): {'freq': 1, 'pmid': {'3662'}},
#  ('hernia', 'tumor'): {'freq': 2, 'pmid': {'3662'}},
#  ('hypoxemia', 'edema'): {'freq': 1, 'pmid': {'3664'}},
#  ('intravascular coagulation', 'cortical infarcts'): {'freq': 1,
#   'pmid': {'3664'}},
#  ('intravascular coagulation', 'coronary arterial thrombi'): {'freq': 1,
#   'pmid': {'3664'}},
#  ('intravascular coagulation', 'myocardial infarction'): {'freq': 1,
#   'pmid': {'3664'}},
#  ('cortical infarcts', 'coronary arterial thrombi'): {'freq': 1,
#   'pmid': {'3664'}},
#  ('cortical infarcts', 'myocardial infarction'): {'freq': 1, 'pmid': {'3664'}},
#  ('coronary arterial thrombi', 'myocardial infarction'): {'freq': 1,
#   'pmid': {'3664'}},
#  ('hypotension', 'intravascular coagulation'): {'freq': 1, 'pmid': {'3664'}},
#  ('graft versus host reaction', 'lymphoproliferative diseases'): {'freq': 1,
#   'pmid': {'3682'}},
#  ('blindness', 'amaurosis traumatica'): {'freq': 1, 'pmid': {'3686'}},
#  ('blindness', 'cranial injury'): {'freq': 1, 'pmid': {'3686'}},
#  ('blindness', 'canalis opticus syndrome'): {'freq': 1, 'pmid': {'3686'}},
#  ('amaurosis traumatica', 'cranial injury'): {'freq': 1, 'pmid': {'3686'}},
#  ('amaurosis traumatica', 'canalis opticus syndrome'): {'freq': 1,
#   'pmid': {'3686'}},
#  ('cranial injury', 'canalis opticus syndrome'): {'freq': 1, 'pmid': {'3686'}},
#  ('injury to the deep structures', 'deformities'): {'freq': 1,
#   'pmid': {'3697'}},
#  ('chronic liver disease', 'chronic hepatitis'): {'freq': 1, 'pmid': {'3720'}},
#  ('chronic liver disease', 'cirrhosis of liver'): {'freq': 1,
#   'pmid': {'3720'}},
#  ('chronic hepatitis', 'cirrhosis of liver'): {'freq': 1, 'pmid': {'3720'}},
#  ('toxic hepatitis', 'cirrhosis'): {'freq': 1, 'pmid': {'3720'}},
#  ('metabolic acidosis', 'hypothyroid'): {'freq': 1, 'pmid': {'3759'}},
#  ('leukemia', 'aplastic anemia'): {'freq': 9,
#   'pmid': {'12847',
#    '21931',
#    '30194',
#    '34323',
#    '36019',
#    '3769',
#    '44107',
#    '8180'}},
#  ('leukemia', 'infectious diseases'): {'freq': 1, 'pmid': {'3769'}},
#  ('leukemia', 'cardiac, respiratory, and renal diseases'): {'freq': 1,
#   'pmid': {'3769'}},
#  ('aplastic anemia', 'infectious diseases'): {'freq': 1, 'pmid': {'3769'}},
#  ('aplastic anemia', 'cardiac, respiratory, and renal diseases'): {'freq': 1,
#   'pmid': {'3769'}},
#  ('infectious diseases',
#   'cardiac, respiratory, and renal diseases'): {'freq': 1, 'pmid': {'3769'}},
#  ('refractory leukemia', 'aplastic anemia'): {'freq': 1, 'pmid': {'3769'}},
#  ('muscular dystrophies', 'neuromuscular diseases'): {'freq': 2,
#   'pmid': {'36240', '3799'}},
#  ('labour', 'complication'): {'freq': 1, 'pmid': {'3899'}},
#  ('uterine hyperactivity', 'complication'): {'freq': 1, 'pmid': {'3899'}},
#  ('lipolysis', 'acidosis'): {'freq': 8,
#   'pmid': {'3944', '3945', '54123', '9778'}},
#  ('respiratory insufficiency', 'bronchitis'): {'freq': 1, 'pmid': {'3948'}},
#  ('respiratory insufficiency', 'breathlessness'): {'freq': 1,
#   'pmid': {'3948'}},
#  ('bronchitis', 'breathlessness'): {'freq': 1, 'pmid': {'3948'}},
#  ('hypoxia', 'bronchitis'): {'freq': 1, 'pmid': {'3948'}},
#  ('acute myocardial infarction', 'ami'): {'freq': 2, 'pmid': {'3949'}},
#  ...}

# %%
df = create_df_from_pairs2(d)
df
# Out:
# Creating DataFrame:   0%|          | 0/18237 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 from co_occurence import create_df_from_pairs
# ----> 2 df = create_df_from_pairs(d)
#       3 df
#
# File ~/EasyNer/scripts/co_occurence.py:132, in create_df_from_pairs(d)
#     129 l = []
#     131 for (e1, e2), val in tqdm(d.items(), desc="Creating DataFrame"):
# --> 132     l.append([e1, e2, val["freq"], ",".join(val["pmid"]), "; ".join(val["sent"])])
#     134 return pd.DataFrame(
#     135     l, columns=["entity_1", "entity_2", "frequency", "pmids", "sentences"]
#     136 ).sort_values("frequency", ascending=False)
#
# KeyError: 'sent'

# %% [markdown]
# # Pairs ex: chemical-disease

# %%
from co_occurence import get_pairs
d_ = get_pairs(sorted_files[:20], entity1="disease", entity2="phenoma")
d_
# Out:
# Processing files:   0%|          | 0/20 [00:00<?, ?it/s]
# Processing files: 100%|██████████| 20/20 [00:09<00:00,  2.19it/s]
# {('depression', 'stream'): {'freq': 1,
#   'pmid': {'168'},
#   'sent': {'In 4 dogs injected intravenously (i.v.) with 125I labeled fibrinogen, 51Cr labeled platelets and 99mTc labeled albumin, and subjected to successively increasing amounts of i.v. infused monomethylmethacrylate, doses corresponding to the amounts released into the blood stream following implantation of acrylic cement during total hip replacements did not affect the clotting mechanism, did not cause trapping of platelets and fibrin in the lungs, did not generate fat emboli, and did not cause depression of the arterial oxygen tension or blood pressure.'}},
#  ('pneumococcal', 'current'): {'freq': 1,
#   'pmid': {'421'},
#   'sent': {'The quellung test and gentamicin plate show improved sensitivity over current techniques for pneumococcal detection and can be recommended for general use.'}},
#  ('pdi', 'current'): {'freq': 1,
#   'pmid': {'507'},
#   'sent': {'Skin potential, short-circuit current and their relationship to PDI were discussed.'}},
#  ('pneumonia', 'current'): {'freq': 2,
#   'pmid': {'553655', '792'},
#   'sent': {'In discussing current concepts of treatment, several well-known methods are emphasized, as well as newer developments, knowledge of which is essential for optimal treatment of pneumonia.',
#    'Mothers were asked about their past and current smoking habits and whether their children had ever had pneumonia or severe bronchitis.'}},
#  ('epstein - barr virus infection', 'current'): {'freq': 2,
#   'pmid': {'1126', '163004'},
#   'sent': {'On the basis of detectable anti-EA and/or the early absence and late emergence of anti-EBNA, four of these 14 individuals showed evidence of a current or very recent primary Epstein-Barr virus infection.',
#    'Since it is not known that many children with infectious mononucleosis do not develop heterophil antibodies, we looked for evidence of current or recent Epstein-Barr virus infection in young patients with these neurologic diseases by using serodiagnostic procedures for detection and titration of antibodies to various antigens related to Epstein-Barr virus.'}},
#  ('xeroderma pigmentosum', 'current'): {'freq': 1,
#   'pmid': {'1751'},
#   'sent': {'The general features of the results were consistent with current concepts of DNA excision repair, in that breaks appeared rapidly after UV, and resealed slowly in normal fibroblasts, whereas breaks did not appear in those cells of patients with xeroderma pigmentosum (XP) that are known to have defects in DNA repair synthesis.'}},
#  ('xp', 'current'): {'freq': 1,
#   'pmid': {'1751'},
#   'sent': {'The general features of the results were consistent with current concepts of DNA excision repair, in that breaks appeared rapidly after UV, and resealed slowly in normal fibroblasts, whereas breaks did not appear in those cells of patients with xeroderma pigmentosum (XP) that are known to have defects in DNA repair synthesis.'}},
#  ('malaria', 'monsoon'): {'freq': 1,
#   'pmid': {'1984'},
#   'sent': {'A. b. balabacensis appeared to be transmitting malaria all the year round in the deep forest but only in the monsoon season in the forest fringe.'}},
#  ('ventricular arrhythmias', 'current'): {'freq': 2,
#   'pmid': {'2004', '397917'},
#   'sent': {'In the coronary care unit ventricular arrhythmias are more frequent than was originally believed and current research suggests that they have little if any predictive value in defining individuals who would develop ventricular fibrillation.',
#    'The ventricular arrhythmias responded to intravenous administration of lidocaine and to direct current electric shock; ventricular pacing was required in some instances and intravenous administration of propranolol combined with ventricular pacing in one.'}},
#  ("down's syndrome", 'current'): {'freq': 3,
#   'pmid': {'147628', '2011'},
#   'sent': {"A close examination of that literature, coupled with a look at findings from two current early education projects for Down's syndrome children, revealed that psychometrically defined educability is far more common in Down's syndrome persons than a cursory review of the literature would lead to believe.",
#    "Some observations were offered as to the effectiveness of past and current drugs on Down's syndrome and some methodological problems relating to drug studies presented."}},
#  ('tumour', 'precipitation'): {'freq': 3,
#   'pmid': {'173807', '176757', '2161'},
#   'sent': {'An inhibitor of the enzyme in the tumour extracts, which was dissociable from the enzyme at the (NH4) 2SO4 precipitation step of purification, had a mol.',
#    'Incorporation of labelled precursor, glycin-1-14C, into the fraction and individual subfractions of blood serum immunoglobulin G (namely into protein positively reacting in the precipitation test) testifies to the fact that at early stages of the tumour development in the rat organism there occurs an intensive synthesis of protein peculiar to hepatoma PC-1.',
#    'Morphological resemblances between the brain-specific alpha2-glycoprotein immuno-precipitation lines obtained from astrocytoma cells and from normal cerebral white matter treated with neuraminidase are discussed in relation to experimental and clinical studies of tumour cells treated with neuraminidase.'}},
#  ('acidophilia', 'flooding'): {'freq': 1,
#   'pmid': {'2567'},
#   'sent': {'For example, the acidophilia of hypochlorite-treated sections was found to be restored after flooding them with hydriodic acid followed by the extraction of the liberated iodine with an alcohol.'}},
#  ('chest infections', 'current'): {'freq': 1,
#   'pmid': {'2621'},
#   'sent': {'The clinical importance of these findings is still being studied but our experience has shown that patients with chest infections should have effective antipneumococcal antibiotics as part of their regimen and that the laboratory diagnosis may be made quickly and accurately by counter-current immunoelectrophoresis.'}},
#  ('allergy', 'smoke'): {'freq': 1,
#   'pmid': {'2631'},
#   'sent': {'This tobacco smoke-induced allergy is probably related to a blockade of adrenergic receptors and not to an immunologic phenomenon.'}},
#  ('hemolysis', 'low temperature'): {'freq': 2,
#   'pmid': {'3160'},
#   'sent': {'The lysis of human erythrocytes by the hemolysin was dependent of temperature and no hemolysis occurred at low temperature (0-4 C), but the hemolysin was adsorbed on human erythrocytes even at low temperature.'}},
#  ('iatrogenic diseases', 'flood'): {'freq': 1,
#   'pmid': {'3849'},
#   'sent': {'However, each advance has its drawbacks: the growing incidence of iatrogenic diseases, the overwhelming literature, the flood of congresses, the record-breaking mentality of many clinicians and the hunting and collecting instinct for "interesting cases".'}},
#  ('viral and tuberculosis meningitis', 'Precipitation'): {'freq': 1,
#   'pmid': {'4042'},
#   'sent': {'Precipitation band was not observed in normal children cases of viral and tuberculosis meningitis.'}},
#  ('gastro - oesophageal disorders', 'current'): {'freq': 1,
#   'pmid': {'5044'},
#   'sent': {'Various methods of investigating and treating patients with gastro-oesophageal disorders are described and the rationale of current concepts is outlined.'}},
#  ('allergy', 'Current'): {'freq': 1,
#   'pmid': {'5043'},
#   'sent': {'Current management involves multiple therapeutic modalities of which we believe tube and allergy are most efficient.'}},
#  ('glycemia', 'precipitation'): {'freq': 1,
#   'pmid': {'5200'},
#   'sent': {'In the enzymatic procedure for blood sugar by means of glucose oxidase, acid protein precipitation of blood by perchloric acid or trichloracetic acid liberated oxidizing substances, which enhanced the coloration density in oxidizing the reduced chromogen of the reaction mixture, independently of the hydrogen peroxide generated from glucose, and would give false high values of glycemia, if additional precautions had not been taken.'}},
#  ('hernias', 'current'): {'freq': 1,
#   'pmid': {'5786'},
#   'sent': {"The management of hernias, hydroceles and undescended testicles is reviewed on the basis of current practice as reported in recent literature and of the author's experience at Addington Hospital, Durban."}},
#  ('hydroceles', 'current'): {'freq': 1,
#   'pmid': {'5786'},
#   'sent': {"The management of hernias, hydroceles and undescended testicles is reviewed on the basis of current practice as reported in recent literature and of the author's experience at Addington Hospital, Durban."}},
#  ('undescended testicles', 'current'): {'freq': 1,
#   'pmid': {'5786'},
#   'sent': {"The management of hernias, hydroceles and undescended testicles is reviewed on the basis of current practice as reported in recent literature and of the author's experience at Addington Hospital, Durban."}},
#  ('cancer', 'extreme heat'): {'freq': 1,
#   'pmid': {'6145'},
#   'sent': {'The extreme heat sensitivity of cytotoxic T-lymphocytes raises important questions about the possible effects of hyperthermic treatment on the immune competence of cancer patients.'}},
#  ('steatorrhea', 'precipitation'): {'freq': 2,
#   'pmid': {'447041', '6360'},
#   'sent': {'Abnormal biliary secretion or intraluminal acidic precipitation of bile acids could contribute to the steatorrhea of pancreatic insufficiency.',
#    'After a conventional test meal, patients with large resections and severe steatorrhea had significantly lower aqueous phase concentrations of bile acids (and fatty acids) than patients with smaller resections or control subjects, explained in part by intraluminal precipitation of about one-half of the bile acids during digestion.'}},
#  ('hypoxia', 'wave'): {'freq': 7,
#   'pmid': {'205527', '447474', '66128', '6671'},
#   'sent': {'Arousal from eucapnic hypoxia occurred at a SaO2 of 87.5 +/- 2.6% (mean +/- SE) during slow-wave sleep (SWS), and at a SaO2 of 70.5 +/- 3.4% during rapid-eye-movement (REM) sleep (P less than 0.005).',
#    'Phosvitin alone was found to prevent the hypoxia-induced T-wave changes (flattening or disappearance), which were also temporarily aggravated by injection of noradrenaline.',
#    'Since the a-wave is not immediately affected by hypoxia, this increase in c-wave amplitude may be related to the movement of the rods toward the pigmented epithelium, which would cause a greater than normal change in extracellular [K+] near the apical membrane in response to a light stimulus, leading to an increase in c-wave amplitude.',
#    'The particular statistical characteristics of SSCs generated during further increase in oxygen deficit can be accounted for by simultaneous generation of responses in some subcortical areas to single volleys of impulses from a hypothetical pacemaker, accompanied by a passive wave propagation towards a cortex completetly depressed by hypoxia',
#    'These cell movements appear to be correlated with the marked increase in ERG c-wave amplitude which we consistently observe during hypoxia in trout.'}},
#  ('hypertension', 'current'): {'freq': 14,
#   'pmid': {'11397',
#    '151613',
#    '15323',
#    '237326',
#    '30767',
#    '335942',
#    '392404',
#    '423596',
#    '490109',
#    '526813',
#    '536966',
#    '9634'},
#   'sent': {'Although current or past use of oral contraceptives may have increased the blood pressure and risk of SAH in a few women, the most important factor in determining this risk was hypertension.',
#    'In order to clarify current opinion on aspects of the management of hypertension, a postal questionnaire was sent to all 420 general practitioners in the Lothian Health Board Area.',
#    'In this monograph we have presented (1) a classification, which correlates well with those currently in use, of the types of hypertension and their causes; (2) a brief review of current fact and theory regarding the effect of hypertension on maternal and perinatal morbidity and mortality; (3) a detailed approach to monitoring the physical and laboratory parameters of the parturient; (4) a rational approach to monitoring the fetoplacental unit; and (5) an analysis of currently available therapeutic regimens that may alter the course of hypertension in pregnancy sufficiently to increase fetal salvage and decrease maternal complications.',
#    'Renin-aldosterone profiling in current clinical practice seems useful mainly in the detection of patients with curable forms of secondary hypertension.',
#    'Sixty-two adults with a current diagnosis of significant hypertension and accompanying moderate to severe anxiety were medicated with lorazepam or with placebo for a period of 4 weeks.',
#    'The best prospect for improved management of hypertension probably lies in earlier treatment with current drug combinations.',
#    'The current use of propranolol in hypertension as regards dosage, dose intervals and starting doses is also outlined.',
#    'The management of hypertension with current hypotensive drugs on the South African pharmaceutical market is reviewed.',
#    'The physician may improve his/her management of hypertensive patients by: (1) anticipating prevalent myths and misconceptions which patients have concerning hypertension; (2) alleviating patient anxiety by stressing that control of blood pressure decreases the likelihood of complications; (3) effectively communicating to each patient the current status of his/her condition at each visit; and (4) initiating discussion of side effects through direct questioning for those effects most frequently seen.',
#    'This article is a review of current concepts on hypertension in children and adolescents.',
#    'This article reviews the current beta-blocking agents, with regard to their usage, side-effects and role in the treatment of hypertension.',
#    'Through a review of current literature and two recent cases from The Milton S. Hershey Medical Center, we have attempted to elucidate a common physical finding, acute hypertension associated with blunt chest trauma, and prove its significance as a diagnostic clue to traumatic rupture of the aorta.'}},
#  ('subpleural edema', 'haziness'): {'freq': 1,
#   'pmid': {'9863'},
#   'sent': {'Inflation of the interstitial medium is reflected by the appearance of Kerley B lines, haziness of the vascular contours and sometimes an axillary bordering line due to subpleural edema.'}},
#  ('pulmonary edema', 'flooding'): {'freq': 1,
#   'pmid': {'9873'},
#   'sent': {'The authors present two cases of unsuccessful hanging which hat lead to a very severe neurological picture and especially the very rapid appearance of acute pulmonary edema resulting in a vertiable flooding of the alveoli.'}},
#  ('tumor', 'stream'): {'freq': 10,
#   'pmid': {'10081', '190077', '556352'},
#   'sent': {'(2) Number of tumor cells detected in the blood stream was within the same range in the control mice and the Tx-X-BM mice after intramuscular tumor-grafting.',
#    '(2) Tumor size is a macroscopical index of the risk of the liberation of tumor cells into the blood stream.',
#    '1-(2-Chloroethyl)-3-cyclohexyl-1-nitrosourea (NSC 79037), a nitro-sourea effective in the palliation of L5178Y/AR, temporarily halts the influx of enzyme into the blood stream, as does surgical excision of the s.c. tumor nodules.',
#    'A study was undertaken to investigate the mechanism of liberation of tumor cells into the blood stream in connection with the process of tumor growth, using three strains of ascites tumor such as Yoshida sarcoma (YS) with infiltrative growth pattern, AH100B with expansive one, and AH109A with intermediate one.',
#    'The tumour strains in order of the number of the circulating tumor cells are YS, AH109A, and AH100B. (5) In YS and AH109A, the transition of the number of tumor cells liberated into the blood stream is closely related to the growth process of tumor tissue.'}},
#  ('hypoxia', 'high temperature'): {'freq': 1,
#   'pmid': {'10426'},
#   'sent': {'After AP-A treatment, the cardiac contractility was more resistant to hypoxia and to low or high temperature stress than ouabain-treated or control preparations.'}},
#  ('acidosis', 'current'): {'freq': 3,
#   'pmid': {'10549', '31464'},
#   'sent': {'Acidosis did not influence the steady state inactivation but altered the kinetics of inactivation of the slow inward current and induced an increase of tauinactivation and taurecovery.',
#    'In sheep Purkinje fibres, acidosis shifts the steady-state current-voltage relation in an inward direction over a wide range of negative potentials.',
#    'This indicates that those forms of acidosis used in the present experiments caused their negative inotropic effect not exclusively via a depression of the Ca current.'}},
#  ('depression', 'current'): {'freq': 18,
#   'pmid': {'10549',
#    '17921',
#    '23937',
#    '282369',
#    '311442',
#    '31690',
#    '355153',
#    '355600',
#    '402588',
#    '459216',
#    '486241',
#    '497374',
#    '565865'},
#   'sent': {'A search of the current literature suggests that a large number of women who have post-hysterectomy depression, loss of libido, or other neuroses have a previous history of depression and neurosis, that they have a generally poor knowledge of their own anatomy and physiology, or that they have received poor counselling and explanation from their own doctor.',
#    'According to the equation above, the depression upon cell multiplication was calculated, when the values of voltage and current time were given.',
#    'In those patients presenting with depression, it is important to review the current drug therapy in order to assess the part played by these drugs in the development of the depression.',
#    "In unpaired studies, the mean depression of short-circuit current (SCC) resulting from the addition of the uremic serum fraction (21.9+/-2.2%) was significantly greater than the decrease in SCC resulting from either frog Ringer's wash or normal serum fractions.",
#    'Internal Ca in concentrations up to 3.5-10-(7)M caused insignificant depression of K outward current.',
#    'It has evolved into its current structure as a result of certain historical conditions, particularly those following the Great Depression.',
#    'It is suggested that PDR depression with ammonium ions could be the result of the blocking of the chloric pump acting the afferent terminals and creating electromotive power for outward transmembranous chloric current producing depolarization of the afferent fibres.',
#    'Most studies on childhood depression include a wide range of children in spite of the fact that from the data available in current literature it seems justified to distinguish between the different age groups of children, mainly the prepubertal and the adolescent groups.',
#    'TEA (250-500 microM) produced an initial enhancement followed by a slow decline in the amplitude of the endplate potential and EPC, but caused only depression in the amplitude of the miniature endplate potential and current.',
#    'The maximum depression of the pulse II outward current occurred when pulse I voltages lay in the range over which calcium influx is inferred to be greatest; depression of the pulse II current subsided as pulse I potentials approached the putative calcium equilibrium potential.',
#    'These observations suggest depression of the fast current by ethmozin.',
#    'This indicates that those forms of acidosis used in the present experiments caused their negative inotropic effect not exclusively via a depression of the Ca current.',
#    'Two cases of recurrent psychotic depression are reported in which ECT (electroconvulsive therapy) was administered with good results for previous episodes of depression, but treatment of the current episode with combined drug therapy (antidepressant and antipsychotic drugs) in one case and antidepressant chemotherapy in the other resulted in failure to improve.'}},
#  ('haemolysis', 'stream'): {'freq': 1,
#   'pmid': {'10714'},
#   'sent': {'It is proposed that the intravenous injections of paraquat in hypotonic solutions temporarily alter the membranes of the erythrocytes in the blood-stream and make them permeable to paraquat, possibly, as judged from the in vitro experiments, only during a short period of partial haemolysis.'}},
#  ('oropharyngeal cancers', 'smoke'): {'freq': 1,
#   'pmid': {'12456'},
#   'sent': {'In the case of many oropharyngeal cancers in Asia and Africa it is the alkaline slaked lime in the betel quid which is responsible; in the case of gastric cancers it is the reflux of the alkaline duodenal contents into the stomach; in the case of colon it is the absence of roughage, cellulose and vegetable fibres from the diet; in the case of the cervix uteri it is the frequency of coitus which gives rise to a highly alkaline seminal fluid; and in the case of cancer lung it is the alkaline cigarette smoke.'}},
#  ('gastric cancers', 'smoke'): {'freq': 1,
#   'pmid': {'12456'},
#   'sent': {'In the case of many oropharyngeal cancers in Asia and Africa it is the alkaline slaked lime in the betel quid which is responsible; in the case of gastric cancers it is the reflux of the alkaline duodenal contents into the stomach; in the case of colon it is the absence of roughage, cellulose and vegetable fibres from the diet; in the case of the cervix uteri it is the frequency of coitus which gives rise to a highly alkaline seminal fluid; and in the case of cancer lung it is the alkaline cigarette smoke.'}},
#  ('cancer', 'smoke'): {'freq': 5,
#   'pmid': {'12456', '288930', '376126', '454880', '510243'},
#   'sent': {'In the case of many oropharyngeal cancers in Asia and Africa it is the alkaline slaked lime in the betel quid which is responsible; in the case of gastric cancers it is the reflux of the alkaline duodenal contents into the stomach; in the case of colon it is the absence of roughage, cellulose and vegetable fibres from the diet; in the case of the cervix uteri it is the frequency of coitus which gives rise to a highly alkaline seminal fluid; and in the case of cancer lung it is the alkaline cigarette smoke.',
#    'Invasive carcinoma of the larynx was induced in 36.8% of inbred Syrian golden hamsters from strain B10 15.16, susceptible to this type of cancer when exposed to smoke from reference filter cigarettes for 59-80 weeks.',
#    'Relevant studies in experimental animals are discussed in the context of possible mechanisms that could account for the increased risk of cancer in heavy drinkers who smoke.',
#    'These results are discussed with reference to the concept that whole cigarette smoke may be both a potential "initiator" and "promotor" of lung cancer in mice, and that this latter property may be the most important in determining cancer risk.',
#    'While tobacco smoke is known to contain carcinogens, the mechanisms by which alcohol provoke cancer remain obscure; it may act by facilitating the penetration of carcinogens in the mucosa-carcinogens might be present in some alcoholic beverages; a direct action of ethanol can not be excluded.'}},
#  ('psychiatric disorders', 'current'): {'freq': 1,
#   'pmid': {'12619'},
#   'sent': {'This selective review emphasizes advances in neurochemistry which provide a context for current and future research on neurological and psychiatric disorders encountered in clinical practice.'}},
#  ('apnea', 'current'): {'freq': 1,
#   'pmid': {'12687'},
#   'sent': {'The patient is in apnea, unventilated, a catheter brings down to the level of the carena a current of oxygen of 15 liters per minute, the gaseous acidosis is buffered by injections of a solution of molar sodium bicarbonate.'}},
#  ('gaseous acidosis', 'current'): {'freq': 1,
#   'pmid': {'12687'},
#   'sent': {'The patient is in apnea, unventilated, a catheter brings down to the level of the carena a current of oxygen of 15 liters per minute, the gaseous acidosis is buffered by injections of a solution of molar sodium bicarbonate.'}},
#  ('anxiety', 'wave'): {'freq': 1,
#   'pmid': {'13088'},
#   'sent': {"Twenty-five Ss were compared to a matched control group before and after administration of a 3-week alpha-wave biofeedback regimen on a wide variety of criteria that included State-Trait Anxiety, the MMPI, Multiple Affect Adjective Check List, Zuckerman's Sensation Seeking Scale, Watson's Anhedonia Scale, the Brief Psychiatric Rating Scale, and baseline alpha."}},
#  ("watson's anhedonia", 'wave'): {'freq': 1,
#   'pmid': {'13088'},
#   'sent': {"Twenty-five Ss were compared to a matched control group before and after administration of a 3-week alpha-wave biofeedback regimen on a wide variety of criteria that included State-Trait Anxiety, the MMPI, Multiple Affect Adjective Check List, Zuckerman's Sensation Seeking Scale, Watson's Anhedonia Scale, the Brief Psychiatric Rating Scale, and baseline alpha."}},
#  ('anxiety', 'flooding'): {'freq': 3,
#   'pmid': {'13342', '362466', '438794'},
#   'sent': {'Conditions of group systematic desensitization (n = 8), group flooding (n = 7), and a group discussion-placebo control treatment (n = 4) were employed to reduce anxiety about public-speaking in university students.',
#    'Near-maximal anxiety by subjective and behavioral criteria was evoked and terminated in phobic patients by initiation and termination of rapid live confrontation ("flooding in vivo") with the specific stimulus that each avoided, at a time approximating the crest of the circadian cycle of adrenal cortical function.',
#    'The most prominent symptom constellation to appear some time during the course of the illness consisted of emotional lability, anxiety, distractibility, pressured speech, sensory flooding, insomnia, depression, perplexity, agitation, auditory and visual hallucinations, intermittent memory impairment, mutism, disturbances of body image, delusions, apathy, and hypomania.'}},
#  ('lung cancer', 'smoke'): {'freq': 10,
#   'pmid': {'13926', '19028', '274943', '372834', '510243', '54649'},
#   'sent': {'A concise reference to earlier studies and to the present state of knowledge is presented, with a subsequent review of the results of experimental studies dealing with the problem of the synergic action of influenza viruses (type A2, A/PRS, B, Sendai) and of chemical carcinogens (urethane, cancerogenic hydrocarbons, diethylnitrosamines, cigarette smoke) in the pathogenesis of lung cancer.',
#    'Analysis of smoke from the two main types of cigars smoked in the region showed that both had high tar content, but there were marked differences in pH. Smoking cigars with alkaline smoke and high tar had an increased risk for laryngeal cancer in males, whereas other cigars with acid smoke and high tar together with manufactured cigarettes had increased risks for lung cancer.',
#    'The effects of tobacco smoke on lung defences and and function are outlined and the evidence relating cigarette smoking to lung cancer in Australia, the UK and the USA is reviewed.',
#    'The smoker of tobaccos giving a smoke of acid buffering capacity, in order to achieve full nicotine satisfaction, tends to smoke more and to inhale more, thus increasing lung cancer risks, than the smoker of tobaccos giving smoke of less acid or of alkaline buffering capacity.',
#    'These changes are consistent with the hypothesis that, in tobacco smoke, tar is the principal aetiological factor in lung cancer, whereas carbon monoxide or other gaseous constituents are involved in the development of C.H.D.',
#    'These results are discussed with reference to the concept that whole cigarette smoke may be both a potential "initiator" and "promotor" of lung cancer in mice, and that this latter property may be the most important in determining cancer risk.'}},
#  ('renal stones', 'current'): {'freq': 1,
#   'pmid': {'14173'},
#   'sent': {'Since monosodium urate (NaU) may play an important etiologic role in the formation of renal stones containing Ca in patients with hyperuricosuria, the current studies were undertaken to define some of the physiocochemical factors which determine the formation of NaU. In solutions containing Na, uric acid was rapidly transformed to NaU at pH greater than 6.'}},
#  ('hyperuricosuria', 'current'): {'freq': 1,
#   'pmid': {'14173'},
#   'sent': {'Since monosodium urate (NaU) may play an important etiologic role in the formation of renal stones containing Ca in patients with hyperuricosuria, the current studies were undertaken to define some of the physiocochemical factors which determine the formation of NaU. In solutions containing Na, uric acid was rapidly transformed to NaU at pH greater than 6.'}},
#  ('hepatomas', 'precipitation'): {'freq': 2,
#   'pmid': {'14209', '61809'},
#   'sent': {'In liver tissue fixed with potassium pyroantimonate, more inorganic cation precipitation occurs in nucleic of hyperbasophilic foci and hepatomas than within surrounding liver parenchyma.',
#    'Ribonuclease (RNase) activities revealed by the substrate film method were compared with reactions for acid and alkaline RNase obtained by lead precipitation technique in serial sections of preneoplastic livers and hepatomas.'}},
#  ('familial palmo - plantar keratoderma', 'Frost'): {'freq': 1,
#   'pmid': {'14586'},
#   'sent': {'The authors propose to term "familial palmo-plantar keratoderma with epidermolytic hyperkeratosis", those cases of palmo-plantar keratoderma with dominant autosomal transmission and the histopathological aspects of the epidermolytic hyperkeratosis (Frost and Van Scott).'}},
#  ('epidermolytic hyperkeratosis', 'Frost'): {'freq': 2,
#   'pmid': {'14586'},
#   'sent': {'The authors propose to term "familial palmo-plantar keratoderma with epidermolytic hyperkeratosis", those cases of palmo-plantar keratoderma with dominant autosomal transmission and the histopathological aspects of the epidermolytic hyperkeratosis (Frost and Van Scott).'}},
#  ('palmo - plantar keratoderma', 'Frost'): {'freq': 1,
#   'pmid': {'14586'},
#   'sent': {'The authors propose to term "familial palmo-plantar keratoderma with epidermolytic hyperkeratosis", those cases of palmo-plantar keratoderma with dominant autosomal transmission and the histopathological aspects of the epidermolytic hyperkeratosis (Frost and Van Scott).'}},
#  ('frost and van scott', 'Frost'): {'freq': 1,
#   'pmid': {'14586'},
#   'sent': {'The authors propose to term "familial palmo-plantar keratoderma with epidermolytic hyperkeratosis", those cases of palmo-plantar keratoderma with dominant autosomal transmission and the histopathological aspects of the epidermolytic hyperkeratosis (Frost and Van Scott).'}},
#  ('hypotensive', 'current'): {'freq': 2,
#   'pmid': {'15323', '350248'},
#   'sent': {'3 These observations suggest that labetalol possesses important advantages over other vasodilator hypotensive drugs in current use.',
#    'The management of hypertension with current hypotensive drugs on the South African pharmaceutical market is reviewed.'}},
#  ('thrombosis', 'current'): {'freq': 7,
#   'pmid': {'137191', '15352', '300961', '508587', '529232', '607987'},
#   'sent': {'After inducing thrombosis by direct current, pH value of the intima of femoral artery was found decreased.',
#    'Arteries taken from 1 to 3 days after local thrombosis had been induced by the passage of a weak electric current followed by the topical administration of ADP were studied by electronmicroscopy.',
#    'Authors have demonstrated that it is possible to induce arterial thrombosis by applying direct electric current (10 mA -V).',
#    'Minor injury and thrombosis, induced in a short arterial segment by the successive applications of a weak electric current and a dilute solution of ADP, is followed by rapid reconstitution of the endothelium and protracted growth of the medial smooth-muscle cells (SMC).',
#    'Permanent arterial occlusion can be obtained experimentally by using plastic micro-spheres, polymerising materials (Histo-Acryl, Paladur) and direct current thrombosis.',
#    'With a current up to 500 micron A, as well as with the optimum current (2000-2500 micronA), but with an over 3.5 mm diameter of the vessel no complete thrombosis is achieved.'}},
#  ('psychosis', 'current'): {'freq': 1,
#   'pmid': {'15665'},
#   'sent': {'A new theory based on current knowledge of the relationship of dopamine to both disorders is postulated which may explain the relationship between the psychosis and epilepsy which occurs in a subgroup of schizophrenic patients.'}},
#  ('epilepsy', 'current'): {'freq': 1,
#   'pmid': {'15665'},
#   'sent': {'A new theory based on current knowledge of the relationship of dopamine to both disorders is postulated which may explain the relationship between the psychosis and epilepsy which occurs in a subgroup of schizophrenic patients.'}},
#  ('newcastle disease', 'current'): {'freq': 1,
#   'pmid': {'16035'},
#   'sent': {'In an effort to improve current technology for detection of Newcastle disease virus in convalescent birds, a procedure has been developed for efficient reactivation of virus that has been neutralized by antibody.'}},
#  ('bacteremia', 'current'): {'freq': 1,
#   'pmid': {'17018'},
#   'sent': {'Even assuming the unproved hypotheses that rigid adherence to current guidelines would prevent all of these procedure-related cases, 59 cases of bacteremia would still have occurred.'}},
#  ('gastroduodenal mucosal lesions', 'current'): {'freq': 1,
#   'pmid': {'17230'},
#   'sent': {'This article presents an analysis of acute gastroduodenal mucosal lesions (AGML) based on a review of current literature and the personal experience of the authors.'}},
#  ('agml', 'current'): {'freq': 1,
#   'pmid': {'17230'},
#   'sent': {'This article presents an analysis of acute gastroduodenal mucosal lesions (AGML) based on a review of current literature and the personal experience of the authors.'}},
#  ('thromboembolism', 'current'): {'freq': 1,
#   'pmid': {'18329'},
#   'sent': {'Many remain controversial at the current time; for example, the diathesis toward thromboembolism in women taking oral contraceptives.'}},
#  ('chronic myelocytic leukemia', 'precipitation'): {'freq': 1,
#   'pmid': {'18469'},
#   'sent': {'Thymidylate kinase derived from the blast cells of human chronic myelocytic leukemia was purified 2186-fold to near homogeneity by means of alcohol precipitation, alumina-Cgamma gel fractionation, calcium phosphate gel fraction, ultrafiltration, and affinity column chromatography.'}},
#  ('mee', 'current'): {'freq': 2,
#   'pmid': {'18977', '386213'},
#   'sent': {'Appropriate management of recurrent episodes of OM or persistent MEE is unclear but current studies include use of prophylactic antimicrobial agents and a multitype pneumococcal vaccine.',
#    'Only after the development of a reliable animal model can current and future methods of management of MEE be tested under controlled laboratory conditions.'}},
#  ('laryngeal cancer', 'smoke'): {'freq': 5,
#   'pmid': {'19028', '288930'},
#   'sent': {'Analysis of smoke from the two main types of cigars smoked in the region showed that both had high tar content, but there were marked differences in pH. Smoking cigars with alkaline smoke and high tar had an increased risk for laryngeal cancer in males, whereas other cigars with acid smoke and high tar together with manufactured cigarettes had increased risks for lung cancer.',
#    'Nearly half the animals (47.4%) showed laryngeal cancer, including noninvasive carcinoma and carcinoma in situ, which occurred with daily smoke exposures (twice a day for 12 min each time, for 27 sec out of each min) 7 days a week at smoke concentrations of 22%.'}},
#  ('dyserythropoiesis', 'wave'): {'freq': 1,
#   'pmid': {'19032'},
#   'sent': {'An early wave of marked dyserythropoiesis was observed in the engrafted marrow.'}},
#  ('peptic ulcer', 'current'): {'freq': 1,
#   'pmid': {'20385'},
#   'sent': {'Based on the current experimental evidence, a model is proposed for mutual interactions of histamine, prostaglandins, and cyclic AMP in regulation of gastric secretion and pathogenesis of peptic ulcer.'}},
#  ('malignant tumors', 'current'): {'freq': 1,
#   'pmid': {'20794'},
#   'sent': {'Problems in the field of modern hygiene have changed in parallel with the current shift of morbidity and mortality in the direction of non-infections diseases such as vascular and circulatory disturbances and malignant tumors.'}},
#  ('drowsiness', 'wave'): {'freq': 1,
#   'pmid': {'21120'},
#   'sent': {'In only 3 cases it caused drowsiness and in 2 transient T wave inversion.'}},
#  ('gastroesophageal reflux', 'current'): {'freq': 1,
#   'pmid': {'21563'},
#   'sent': {'Although teliologically appealing, the belief that patients with weak lower-esophageal sphincters and gastroesophageal reflux have stronger upper-esophageal sphincters to guard against pharyngeal reflux and aspiration cannot be confirmed by current manometric techniques.'}},
#  ('hypothermia', 'ice'): {'freq': 4,
#   'pmid': {'22255', '300906', '419641'},
#   'sent': {'Combined core and topical hypothermia with ice slush used in valve replacements and combined valve with coronary operations allowed periods of total ischemia up to 134 minutes without signs of detectable myocardial damage.',
#    'Hypothermia by applying ice to the renal surface therefore proved to be equivalent to hypothermia by perfusion.',
#    'They demonstrated an increased ability over similar aged controls to recover from hypothermia induced by 3-minute whole-body ice water immersion, were able to bear litters at 17--28 months of age, showed a delay in the age of onset of visible tumors, and indicated an increase in their average lifespan at late ages.'}},
#  ('tumors', 'ice'): {'freq': 1,
#   'pmid': {'22255'},
#   'sent': {'They demonstrated an increased ability over similar aged controls to recover from hypothermia induced by 3-minute whole-body ice water immersion, were able to bear litters at 17--28 months of age, showed a delay in the age of onset of visible tumors, and indicated an increase in their average lifespan at late ages.'}},
#  ('zollinger - ellison syndrome', 'current'): {'freq': 1,
#   'pmid': {'22304'},
#   'sent': {'The results indicate that patients with Zollinger-Ellison syndrome can be managed medically and, in light of current mortality trends, gain little from the extra risks attending total gastrectomy.'}},
#  ('oedema', 'wave'): {'freq': 3,
#   'pmid': {'23434', '82323'},
#   'sent': {'Nevertheless, the capsulate strains, in contrast to the non-capsulate, are known to require complement attachment for phagocytosis and it is therefore postulated that the toxic by-products released cause the wave of oedema characteristic of pneumococcal lobar pneumonia.',
#    'The effect of inhibitors on the inflammatory oedema elicited by medium-wave ultraviolet radiation (UVB) and long-wave ultraviolet radiation (UVA) in combination with chlorpromazine has been studied in the mouse, by means of a quantitative technique.'}},
#  ('pneumococcal lobar pneumonia', 'wave'): {'freq': 1,
#   'pmid': {'23434'},
#   'sent': {'Nevertheless, the capsulate strains, in contrast to the non-capsulate, are known to require complement attachment for phagocytosis and it is therefore postulated that the toxic by-products released cause the wave of oedema characteristic of pneumococcal lobar pneumonia.'}},
#  ('ear, nose, and throat diseases', 'current'): {'freq': 1,
#   'pmid': {'23470'},
#   'sent': {'The results of physical examination provided current statistics as to the existence of ear, nose, and throat diseases associated with meningitis.'}},
#  ('meningitis', 'current'): {'freq': 2,
#   'pmid': {'23470', '572789'},
#   'sent': {'The results of physical examination provided current statistics as to the existence of ear, nose, and throat diseases associated with meningitis.',
#    'This new prophylactic weapon inspires the authors to suggest a new strategy in the fight against meningitis epidemics caused by meningococcus in the African Sahel area, taking into account the current increase there in serogroup C, against which there is also a vaccine whose efficacy has already been demonstrated.'}},
#  ('eastern equine encephalitis', 'rainfall'): {'freq': 1,
#   'pmid': {'23676'},
#   'sent': {"Reappearance of eastern equine encephalitis (EEE) in Massachusetts residents in the 1970's provided an opportunity to assess the predictive value of data on rainfall, EEE in horses, and carriage of EEE virus (EEEV) by mosquitoes, factors which had been studied annually since the last EEE outbreak in 1955-1956."}},
#  ('eee', 'rainfall'): {'freq': 3,
#   'pmid': {'23676'},
#   'sent': {"Reappearance of eastern equine encephalitis (EEE) in Massachusetts residents in the 1970's provided an opportunity to assess the predictive value of data on rainfall, EEE in horses, and carriage of EEE virus (EEEV) by mosquitoes, factors which had been studied annually since the last EEE outbreak in 1955-1956."}},
#  ('psychiatric', 'wave'): {'freq': 1,
#   'pmid': {'23822'},
#   'sent': {'A lapel badge dosimeter sensitive to short wave UVR has been used in a preliminary trial to survey photosensitivity in psychiatric patients on phenothiazine therapy.'}},
#  ('hepatitis', 'precipitation'): {'freq': 4,
#   'pmid': {'107654', '24265', '419735', '57716'},
#   'sent': {'By using polyethylene glycol precipitation at low concentration (PEG test) and the radiolabeled C1q binding test, immune complexes were detected sera from acute (23/28) and chronic (28/32) hepatitis patients, hemodialyzed patients with chronic hepatitis B surface (HBs) antigenemia (7/19), and asymptomatic HBs antigen carriers (2/11).',
#    'In staining hepatitis antigen in agar, comparison of fixation (using three common fixatives) with unfixed precipitation arcs revealed no recognizable differences in antigenicity induced by fixation.',
#    'The gel precipitation test was used for examinations of 280 HBsAg-positive patients with jaundiced serum hepatitis and 182 subjects with long-term HBs-antigenemia and various degrees of activity of the pathologic process in the liver, in a coded study.',
#    'The use of immunoautoradiography for HBsAg detection increased its primary detection rate in the blood of patients with acute serum hepatitis to 70% (by 12--15% more than in the gel precipitation test).'}},
#  ('rubella', 'precipitation'): {'freq': 2,
#   'pmid': {'25011', '513109'},
#   'sent': {'IgA and IgG antibodies to the ribonucleoprotein component of rubella virus have been demonstrated by radioimmune precipitation in sera from patients with recent but not remote rubella infection.',
#    'Polyethylene glycol (PEG) was used for precipitation of rubella virus haemagglutinating (HA) antigen from the fluid phase of infected Vero cell cultures, maintained with or without calf serum.'}},
#  ('carcinomas', 'current'): {'freq': 3,
#   'pmid': {'25027', '340856', '388686'},
#   'sent': {'A 1976 report of the use of radiofrequency current to devitalize carcinomas in man stimulated this review of the historical background, the presently used techniques, and the problems associated with electrosurgery.',
#    'Less than 40 percent of all carcinomas of the gastrointestinal tract will be controlled by the current modalities of treatment.',
#    'The evident secretory capabilities of these carcinomas suggest obvious diagnostic possibilities and could conceivably lead to a reappraisal of current therapy.'}},
#  ('dry mouth', 'precipitation'): {'freq': 1,
#   'pmid': {'25167'},
#   'sent': {'Other, less common side-effects such as anticholinergic effects (dry mouth, blurred vision, etc.), hypotension, tachycardia and precipitation of epileptic seizures, which occur with the older antipsychotic drugs, have also been reported with loxapine.'}},
#  ('blurred vision', 'precipitation'): {'freq': 1,
#   'pmid': {'25167'},
#   'sent': {'Other, less common side-effects such as anticholinergic effects (dry mouth, blurred vision, etc.), hypotension, tachycardia and precipitation of epileptic seizures, which occur with the older antipsychotic drugs, have also been reported with loxapine.'}},
#  ('hypotension', 'precipitation'): {'freq': 1,
#   'pmid': {'25167'},
#   'sent': {'Other, less common side-effects such as anticholinergic effects (dry mouth, blurred vision, etc.), hypotension, tachycardia and precipitation of epileptic seizures, which occur with the older antipsychotic drugs, have also been reported with loxapine.'}},
#  ('tachycardia', 'precipitation'): {'freq': 1,
#   'pmid': {'25167'},
#   'sent': {'Other, less common side-effects such as anticholinergic effects (dry mouth, blurred vision, etc.), hypotension, tachycardia and precipitation of epileptic seizures, which occur with the older antipsychotic drugs, have also been reported with loxapine.'}},
#  ('epileptic seizures', 'precipitation'): {'freq': 1,
#   'pmid': {'25167'},
#   'sent': {'Other, less common side-effects such as anticholinergic effects (dry mouth, blurred vision, etc.), hypotension, tachycardia and precipitation of epileptic seizures, which occur with the older antipsychotic drugs, have also been reported with loxapine.'}},
#  ('virus infection', 'current'): {'freq': 1,
#   'pmid': {'25664'},
#   'sent': {'pneumoniae and/or Haemophilus spp. or of a current virus infection, suggesting exogenous infection in the majority of these cases.'}},
#  ('infection', 'current'): {'freq': 16,
#   'pmid': {'151573',
#    '228159',
#    '25664',
#    '318786',
#    '325010',
#    '380855',
#    '384573',
#    '433674',
#    '495627',
#    '541497',
#    '569720',
#    '96735'},
#   'sent': {'A rising CF titre and positive LA indicates current infection; reliable prognosis following treatment is given by CF.',
#    'Forty patients and 10 staff had evidence of recent or current infection, while 149 patients and 50 staff had evidence of past infection.',
#    'In patients with a current infection due to M. pneumoniae, suggestive evidence is presented that this agent might be involved in the pathogenesis of the neurological syndromes.',
#    'It is important for practicing physicians to have a clear understanding of current knowledge of the role of cell-mediated immunity in resistance to infection and how this arm of the immune system relates to the diagnosis and therapy of infectious diseases.',
#    'Nineteen of the patients showed evidence of a current M. pneumoniae infection, 32 of a previous infection, and 320 no evidence.',
#    'Of those with recent or current infection, 4 (40%) had abnormal liver function values compared with 25 (12%) of those without HBV markers.',
#    'The "hierarchy" of the individual prognostic parameters has been established: current severe infection, granulocyte count, percentage of the nonmyeloid cells on the bone marrow slides, platelet count, reticulocyte count, 59Fe utilization, and stromal disorganization on the bone marrow biopsy specimen.',
#    'The current treatment should include early valve resection or fulguration followed by observation with emphasis on renal function, blood pressure and infection as opposed to the urographic appearance of the collecting system.',
#    'The potential toxicity of antifungal drugs in current use and the apparent effectiveness of surgical treatment for patients who only have a single focus of infection in bone, without involvement of other tissues, should be noted.',
#    'These results suggest that current susceptibility criteria in use for gentamicin and P. aeruginosa overestimate gentamicin susceptibility, particularly when low-cation growth medium is used for susceptibility testing and when treating disseminated infection.',
#    'These results support the idea that the development of antibody to PENA, like antibody to EA, may represent a current or recent infection with (or reactivation of) H-CMV.',
#    'This resistance is as strong in animals with a current infection as it is in those that have fully recovered from such an infection.',
#    'We review the current knowledge of those antimicrobial substances known to be present in tears and the role they might play in preventing infection.',
#    'pneumoniae and/or Haemophilus spp. or of a current virus infection, suggesting exogenous infection in the majority of these cases.'}},
#  ('increases in blood pressure', 'ice'): {'freq': 1,
#   'pmid': {'26372'},
# ...
#  ('allergic reactions', 'fire'): {'freq': 1,
#   'pmid': {'239051'},
#   'sent': {'Two South American species of the fire ant group, Solenopsis richteri and Solenopsis invicta, now occupy more than 150 million acres in 13 southern states and cause systemic allergic reactions to their stings.'}},
#  ('hypersensitivity', 'fire'): {'freq': 1,
#   'pmid': {'239051'},
#   'sent': {'Hypersensitivity to the imported fire ant continues to be a serious problem in the southern United States and appears to be amenable to properly instituted hyposensitization therapy.'}},
#  ('subarachnoid hemorrhage', 'current'): {'freq': 1,
#   'pmid': {'239472'},
#   'sent': {'It is thought that consideration of such microvascular characteristics, in conjunction with those known to be associated with larger intracranial vessels, adds to current knowledge of the pathophysiology of subarachnoid hemorrhage and may be extrapolated to bear future clinical import.'}},
#  ('hypovolemia', 'smoke'): {'freq': 1,
#   'pmid': {'240158'},
#   'sent': {'The lesion may be secondary to direct damage to the respiratory apparatus from the inhalation of smoke or of toxic or superheated chemicals or from mechanical mechanisms or it may be secondary to indirect damage from hypovolemia, shock, central nervous system disturbances, or drug usage.'}},
#  ('shock', 'smoke'): {'freq': 1,
#   'pmid': {'240158'},
#   'sent': {'The lesion may be secondary to direct damage to the respiratory apparatus from the inhalation of smoke or of toxic or superheated chemicals or from mechanical mechanisms or it may be secondary to indirect damage from hypovolemia, shock, central nervous system disturbances, or drug usage.'}},
#  ('nervous system disturbances', 'smoke'): {'freq': 1,
#   'pmid': {'240158'},
#   'sent': {'The lesion may be secondary to direct damage to the respiratory apparatus from the inhalation of smoke or of toxic or superheated chemicals or from mechanical mechanisms or it may be secondary to indirect damage from hypovolemia, shock, central nervous system disturbances, or drug usage.'}},
#  ('bronchospasm', 'current'): {'freq': 1,
#   'pmid': {'241949'},
#   'sent': {'The current status of beta-adrenergics in the treatment of bronchospasm is discussed.'}},
#  ('respiratory failure', 'low temperature'): {'freq': 1,
#   'pmid': {'242046'},
#   'sent': {'Force decay of slowly paced (12/min) isometric ventricular strips of frog heart at low temperature (+12 degrees C) was studied under standard cellular respiratory failure (3 mM NaCN).'}},
#  ('renovascular hypertension', 'current'): {'freq': 1,
#   'pmid': {'242210'},
#   'sent': {'Because an elevated cardiac output is the hemodynamic function that differentiates these groups, and renovascular hypertension as well, it is the focus of much current work.'}},
#  ('injury', 'smoke'): {'freq': 1,
#   'pmid': {'242281'},
#   'sent': {'The consequences of near-lethal smoke inhalation in dogs were studied for a 72-hour period following injury.'}},
#  ('amnesic syndrome', 'current'): {'freq': 1,
#   'pmid': {'252447'},
#   'sent': {'Two main classes of current theories of the amnesic syndrome are discussed.'}},
#  ('sepsis', 'current'): {'freq': 1,
#   'pmid': {'252820'},
#   'sent': {'Choices of antibiotics for sepsis, where cultures are unavailable, requires a knowledge of current strains in the unit where the patient resides and coverage for both Staphylococcus aureus and Pseudomonas.'}},
#  ('mentally', 'current'): {'freq': 1,
#   'pmid': {'258768'},
#   'sent': {'The road leading to the demise of state responsibility for the seriously mentally ill and the current crisis of abandonment was paved with all the best intentions.'}},
#  ('breast carcinoma', 'wave'): {'freq': 1,
#   'pmid': {'259080'},
#   'sent': {'Thermographic studies of 14 patients with breast carcinoma were performed using two millimeter wave scanners for 30 and 68 GHz.'}},
#  ('hypocomplementemia', 'precipitation'): {'freq': 1,
#   'pmid': {'261514'},
#   'sent': {'The presence of persistent hypocomplementemia suggested the possibility that the cryoglobulin, upon cold-induced precipitation, was capable of activating the complement system.'}},
#  ('upper respiratory tract infections', 'smoke'): {'freq': 1,
#   'pmid': {'262590'},
#   'sent': {'The results reported in this paper indicate that children who smoke regularly have a higher prevalence of upper respiratory tract infections and a higher incidence of the respiratory symptoms, cough, phlegm production with a cold, and shortness of breath, compared with non-smokers.'}},
#  ('respiratory symptoms', 'smoke'): {'freq': 3,
#   'pmid': {'262590', '515496'},
#   'sent': {'Children who report that they smoke cigarettes, also report increased respiratory symptoms.',
#    'It is concluded that the questionnaire technique is valid, and that children who smoke cigarettes are more likely than non-smokers to have respiratory symptoms.',
#    'The results reported in this paper indicate that children who smoke regularly have a higher prevalence of upper respiratory tract infections and a higher incidence of the respiratory symptoms, cough, phlegm production with a cold, and shortness of breath, compared with non-smokers.'}},
#  ('cough', 'smoke'): {'freq': 1,
#   'pmid': {'262590'},
#   'sent': {'The results reported in this paper indicate that children who smoke regularly have a higher prevalence of upper respiratory tract infections and a higher incidence of the respiratory symptoms, cough, phlegm production with a cold, and shortness of breath, compared with non-smokers.'}},
#  ('phlegm', 'smoke'): {'freq': 1,
#   'pmid': {'262590'},
#   'sent': {'The results reported in this paper indicate that children who smoke regularly have a higher prevalence of upper respiratory tract infections and a higher incidence of the respiratory symptoms, cough, phlegm production with a cold, and shortness of breath, compared with non-smokers.'}},
#  ('cold', 'smoke'): {'freq': 1,
#   'pmid': {'262590'},
#   'sent': {'The results reported in this paper indicate that children who smoke regularly have a higher prevalence of upper respiratory tract infections and a higher incidence of the respiratory symptoms, cough, phlegm production with a cold, and shortness of breath, compared with non-smokers.'}},
#  ('shortness of breath', 'smoke'): {'freq': 1,
#   'pmid': {'262590'},
#   'sent': {'The results reported in this paper indicate that children who smoke regularly have a higher prevalence of upper respiratory tract infections and a higher incidence of the respiratory symptoms, cough, phlegm production with a cold, and shortness of breath, compared with non-smokers.'}},
#  ('jaundice', 'current'): {'freq': 2,
#   'pmid': {'263093'},
#   'sent': {'Cases with current jaundice showed highly significant frequency of both HBs-Ag and anti-HBs compared to those with no history or manifest jaundice at the time of study.'}},
#  ('brucellosis', 'precipitation'): {'freq': 1,
#   'pmid': {'263179'},
#   'sent': {'A study on goat brucellosis has been done in the province of San Luis, a semidesertic area (annual precipitation ca.'}},
#  ('bulboventricular malformations', 'Current'): {'freq': 1,
#   'pmid': {'263541'},
#   'sent': {'Current surgical methods enable radical treatment of the most bulboventricular malformations (syn.'}},
#  ('poisoning', 'current'): {'freq': 1,
#   'pmid': {'263876'},
#   'sent': {'The importance of determining acetaminophen plasma concentration at different times to evaluate more precisely the plasma half-life is discussed, along with the current suggested therapy now being recommended for acetaminophen poisoning.'}},
#  ('wound', 'fire'): {'freq': 1,
#   'pmid': {'263931'},
#   'sent': {'Injuries from pistol or .22 rim-fire bullets are confined to tissue and organs directly in the wound track.'}},
#  ('chronic denture stomatitis', 'current'): {'freq': 1,
#   'pmid': {'264550'},
#   'sent': {'A review of the etiology and pathology of chronic denture stomatitis is presented, and two current methods of treatment have been evaluated.'}},
#  ('facial pain', 'current'): {'freq': 1,
#   'pmid': {'265037'},
#   'sent': {'"Atypical facial pain" is the current label for a possibly heterogeneous group of discomforts localized in the lower half of the head and often confused with dental disease.'}},
#  ('dental disease', 'current'): {'freq': 1,
#   'pmid': {'265037'},
#   'sent': {'"Atypical facial pain" is the current label for a possibly heterogeneous group of discomforts localized in the lower half of the head and often confused with dental disease.'}},
#  ('acute leukaemias', 'Current'): {'freq': 1,
#   'pmid': {'265101'},
#   'sent': {'Current concepts underlying the treatment of the acute leukaemias are presented.'}},
#  ('sarcoidosis', 'current'): {'freq': 1,
#   'pmid': {'266069'},
#   'sent': {'The current case emphasizes that biopsy of an intraoral lesion, scalene node biopsy, and Kveim testing are useful in establishing a diagnosis of sarcoidosis.'}},
#  ('hemolysis', 'current'): {'freq': 1,
#   'pmid': {'266714'},
#   'sent': {'Neither the effect of current nor the extent of the rapid Joule-heating to the suspending medium shows a direct correlation with the observed hemolysis.'}},
#  ('volume loss', 'current'): {'freq': 1,
#   'pmid': {'267913'},
#   'sent': {'The degree of volume loss was measured and analysed in 10 respirators which are in current use.'}},
#  ('depression', 'ice'): {'freq': 1,
#   'pmid': {'267952'},
#   'sent': {'A model in which adsorbed antifreezes raise the curvature of growth steps on the ice surface is proposed to account for the observed depression of the temperature at which freezing occurs and agrees well with experimental observations.'}},
#  ('myxoedema', 'climate'): {'freq': 1,
#   'pmid': {'268174'},
#   'sent': {'Myxoedema coma is fortunately rare and is probably rarer in a warm climate such as Australia.'}},
#  ('coma', 'climate'): {'freq': 1,
#   'pmid': {'268174'},
#   'sent': {'Myxoedema coma is fortunately rare and is probably rarer in a warm climate such as Australia.'}},
#  ('horse sickness', 'wind'): {'freq': 1,
#   'pmid': {'269203'},
#   'sent': {'Analyses of outbreaks of African horse sickness showed that movement of infected Culicoides midges on the wind was most likely responsible for the spread of the disease over the sea from Morocco to Spain in 1966, from Turkey to Cyprus in 1960, and from Senegal to the Cape Verde Islands in 1943.'}},
#  ('platelet aggregation', 'wave'): {'freq': 4,
#   'pmid': {'269449', '318874', '399526', '603780'},
#   'sent': {'At higher concentrations (10-50 muM), propranolol abolished the second wave of platelet aggregation induced by ADP and epinephrine, and inhibited aggregation induced by collagen, thrombin, and the ionophore A23187.',
#    'The specificity of azo analog I is demonstrated by its selective inhibition of the second wave of either ADP- or epinephrine-induced platelet aggregation.',
#    'These studies support the concept that the second wave of platelet aggregation is mediated through free radical reactions.',
#    'Ticlopidine, known to inhibit the primary wave of ADP-induced platelet aggregation and to increase the bleeding time, can modify platelet prostaglandin metabolism.'}},
#  ('extracranial arterial disease', 'Current'): {'freq': 1,
#   'pmid': {'269715'},
#   'sent': {'Current methods of assessing and treating common problems in peripheral arterial surgery are reviewed, Topics specifically excluded are extracranial arterial disease, renovascular reconstruction, the thoracic aorta, and the upper limb arteries.'}},
#  ('herpes labialis', 'current'): {'freq': 1,
#   'pmid': {'270069'},
#   'sent': {'A retrospective 12-year investigation of 1,788 professional school students from the schools of medicine, veterinary medicine, dental medicine, nursing, and dental hygiene was conducted by the mailed distribution of questionnaires requesting information on current and prior disease history of recurrent herpes labialis (RHL).'}},
#  ('rhl', 'current'): {'freq': 1,
#   'pmid': {'270069'},
#   'sent': {'A retrospective 12-year investigation of 1,788 professional school students from the schools of medicine, veterinary medicine, dental medicine, nursing, and dental hygiene was conducted by the mailed distribution of questionnaires requesting information on current and prior disease history of recurrent herpes labialis (RHL).'}},
#  ('disorder of erythropoiesis', 'current'): {'freq': 1,
#   'pmid': {'270348'},
#   'sent': {'The question of fetal hemoglobin synthesis reactivation is a current topic both from the aspect of the genetic regulation of synthesis and from the aspect of the disorder of erythropoiesis in malignant diseases.'}},
#  ('malignant diseases', 'current'): {'freq': 1,
#   'pmid': {'270348'},
#   'sent': {'The question of fetal hemoglobin synthesis reactivation is a current topic both from the aspect of the genetic regulation of synthesis and from the aspect of the disorder of erythropoiesis in malignant diseases.'}},
#  ('cyanosis of the toes and fingers', 'shower'): {'freq': 1,
#   'pmid': {'270795'},
#   'sent': {'Three weeks after electrocoagulation of an enormous epithelioma of the floor of the mouth, a 62-year-old man presented after a shower-bath with symmetrical cyanosis of the toes and fingers with painful oedema coloured by livedo reticularis of the lower third of the legs and forearms.'}},
#  ('oedema', 'shower'): {'freq': 1,
#   'pmid': {'270795'},
#   'sent': {'Three weeks after electrocoagulation of an enormous epithelioma of the floor of the mouth, a 62-year-old man presented after a shower-bath with symmetrical cyanosis of the toes and fingers with painful oedema coloured by livedo reticularis of the lower third of the legs and forearms.'}},
#  ('livedo reticularis of the lower third of the legs and forearms',
#   'shower'): {'freq': 1,
#   'pmid': {'270795'},
#   'sent': {'Three weeks after electrocoagulation of an enormous epithelioma of the floor of the mouth, a 62-year-old man presented after a shower-bath with symmetrical cyanosis of the toes and fingers with painful oedema coloured by livedo reticularis of the lower third of the legs and forearms.'}},
#  ('temporomandibular ankylosis', 'current'): {'freq': 1,
#   'pmid': {'271015'},
#   'sent': {'The condition does not appear to be included in current teaching or existing nomenclature and consists of an acquired absence of the mandibular condyles, unassociated with temporomandibular ankylosis or aural/facial anomalies.'}},
#  ('aural / facial anomalies', 'current'): {'freq': 1,
#   'pmid': {'271015'},
#   'sent': {'The condition does not appear to be included in current teaching or existing nomenclature and consists of an acquired absence of the mandibular condyles, unassociated with temporomandibular ankylosis or aural/facial anomalies.'}},
#  ('condylar aplasia or hypoplasia', 'current'): {'freq': 1,
#   'pmid': {'271015'},
#   'sent': {'Whereas previous writers have regarded the condition as a prenatal condylar aplasia or hypoplasia, morphanalysis studies of the four current cases have shown that the probable aetiology is postnatal local disturbance in the condylar region.'}},
#  ('chromosomal abnormality', 'current'): {'freq': 1,
#   'pmid': {'271143'},
#   'sent': {'Our current interpretation of the chromosomal abnormality is that it is a reciprocal translocation, t (15;17) (q22; q21).'}},
#  ('lens opacities', 'current'): {'freq': 1,
#   'pmid': {'271404'},
#   'sent': {'Lens opacities may also be caused by chemical burns and remote forces such as electrical current and radiational injury.'}},
#  ('lymphocytosis', 'current'): {'freq': 1,
#   'pmid': {'272943'},
#   'sent': {'Nineteen other patients showed a positive response and several factors may have contributed to this: two underwent a "rebound" lymphocytosis after stopping treatment, nine had current or intercurrent infections, two had persistent unexplained bone-marrow lymphocytosis, but six had no causative symptoms and thus their responses were "true false-positives."'}},
#  ...}

# %%
from co_occurence import create_df_from_pairs
df_ = create_df_from_pairs(d_)
df_
# Out:
# Creating DataFrame: 100%|██████████| 2091/2091 [00:00<00:00, 634287.24it/s]
#                          entity_1 entity_2  frequency  \
# 145                        cancer  current         40
# 111                          pain  current         27
# 174                    depression     wave         26
# 219                         tumor  current         25
# 245                      seizures     wave         19
# ...                           ...      ...        ...
# 833            adrenal hemorrhage  current          1
# 831   deficiency of ldl receptors  current          1
# 829                     lipolysis      ice          1
# 828            amebic peritonitis  current          1
# 2090              kidney injuries  current          1
#
#                                                   pmids  \
# 145   397756,453167,469237,107379,376111,380617,3677...
# 111   298841,285695,474949,380617,316769,359212,4610...
# 174   335012,607494,46817,426983,427282,65272,234363...
# 219   68945,192689,367731,95452,167462,424548,189626...
# 245   97076,67023,416952,89944,477631,388250,477642,...
# ...                                                 ...
# 833                                              205758
# 831                                              205553
# 829                                              205405
# 828                                              205190
# 2090                                             608161
#
#                                               sentences
# 145   These observations are discussed in terms of t...
# 111   Results were as follows: no effect in nine cas...
# 174   At the maximum tolerable dose of 1400 mg/m2, t...
# 219   Moreover, according to our current estimate, t...
# 245   The EEG showed right parietal sharp wave disch...
# ...                                                 ...
# 833   Two-thirds of the current series had impaired ...
# 831   The current findings are consistent with the c...
# 829   In the reconstructed lipid micelles which cons...
# 828   Emetine hydrochloride alone or followed by met...
# 2090  Treatment of kidney injuries has classically b...
#
# [2091 rows x 5 columns]

# %%
from co_occurence import save_pairs_to_csv

# save_pairs_to_csv(df_, "/home/x_caoll/EasyNer/results/co_occurrences.csv")
df_.to_excel("/home/x_caoll/EasyNer/results/co_occurrences.xlsx")
